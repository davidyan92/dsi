# %%
import pandas as pd
pd.set_option('max_colwidth',100)
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
from sklearn import preprocessing as pp
import pickle
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Plot Charts

# %%
couple_data = pd.read_pickle('./couple_data')

# %%
# See relationship for continuous features
plt.figure(figsize=(20,10))
couple_data_cont = couple_data.select_dtypes(include=['float32','float64','int64','int8'])
couple_data_cat = couple_data[[col for col in couple_data.columns if col not in couple_data_cont]]
corr = couple_data_cont.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr**2, mask=mask,annot=True)

# %%
# p value for highly correlated variables
print(sp.stats.pearsonr(couple_data['how_long_ago_first_met'], couple_data['how_long_relationship']))
print(sp.stats.pearsonr(couple_data['how_long_ago_first_met'], couple_data['how_long_ago_first_cohab']))
print(sp.stats.pearsonr(couple_data['how_long_ago_first_met'], couple_data['how_long_ago_first_romantic']))
print(sp.stats.pearsonr(couple_data['how_long_relationship'], couple_data['how_long_ago_first_romantic']))
print(sp.stats.pearsonr(couple_data['how_long_ago_first_cohab'], couple_data['how_long_ago_first_romantic']))
print(sp.stats.pearsonr(couple_data['how_long_ago_first_cohab'], couple_data['how_long_relationship']))
# Out:
# (0.96397185210540226, 0.0)
# (0.89266288215645995, 0.0)
# (0.96413106707755047, 0.0)
# (0.99964731247755167, 0.0)
# (0.91633225123066497, 0.0)
# (0.91681590535604551, 0.0)

# %%
# P values are below 0.05, correlation between variables are statistically insignificant
# Do not need to remove them

# %%
couple_data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1647 entries, 33536 to 4621371
# Data columns (total 28 columns):
# pphouse                     1647 non-null object
# hhinc                       1647 non-null object
# pprent                      1647 non-null object
# higher_income_earner        1647 non-null object
# same_high_school            1647 non-null object
# same_college_uni            1647 non-null object
# grow_up_same_city_town      1647 non-null object
# parent_alive                1647 non-null object
# met_partner_work            1647 non-null object
# friend_intro_partner        1647 non-null object
# self_intro_partner          1647 non-null object
# q24_met_online              1647 non-null category
# q24_school                  1647 non-null category
# q24_bar_restaurant          1647 non-null category
# q24_private_party           1647 non-null category
# same_sex_couple             1647 non-null category
# met_through_friends         1647 non-null category
# met_through_family          1647 non-null category
# married                     1647 non-null category
# parental_approval           1647 non-null category
# couple_politic_view_comb    1647 non-null object
# couple_evang_comb           1647 non-null object
# couple_relig_comb           1647 non-null object
# couple_race_comb            1647 non-null object
# gender_work_status          1647 non-null object
# gender_internet_access      1647 non-null object
# hhhead_gender               1647 non-null object
# marriage_count_gender       1647 non-null object
# dtypes: category(9), object(19)
# memory usage: 272.0+ KB

# %%
# income disparity between couples doesnt affect relationship outcome
sns.countplot(x=couple_data_cat['higher_income_earner'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# grow_up_same_city_town doesnt affect relationship outcome
plt.figure(figsize=(10,5))
sns.countplot(x=couple_data_cat['grow_up_same_city_town'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# parent_alive doesnt affect relationship outcome
plt.figure(figsize=(10,5))
sns.countplot(x=couple_data_cat['parent_alive'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# friend_intro_partner doesnt affect relationship outcome
plt.figure(figsize=(10,5))
sns.countplot(x=couple_data_cat['friend_intro_partner'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# self_intro_partner doesnt affect relationship outcome
plt.figure(figsize=(10,5))
sns.countplot(x=couple_data_cat['self_intro_partner'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# met_through_friends doesnt affect relationship outcome
sns.countplot(x=couple_data_cat['met_through_friends'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# married doesnt affect relationship outcome
sns.countplot(x=couple_data_cat['married'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# parental_approval doesnt affect relationship outcome
sns.countplot(x=couple_data_cat['parental_approval'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# whether parents are alive against relationship outcome
plt.figure(figsize=(10,5))
sns.countplot(x=couple_data_cat['parent_alive'],hue=couple_data_cont['relationship_outcome_6yrs'])

# %%
# What about years of education
cols = ['couple_yrsed_diff','couple_moms_yrsed_diff','relationship_outcome_6yrs']
couple_data_cont[cols].boxplot(by='relationship_outcome_6yrs', figsize=(20,10))
# Out:
# /Users/david.yan/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1501d780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a153a9978>], dtype=object)

# %%
# Relationship seem to be due to imbalance data
# Resample Data for more accurate picture of relationships
# Convert categorical into dummies
import patsy
f = 'relationship_outcome_6yrs ~ ' + ' + '.join([col for col in couple_data.columns if col != 'relationship_outcome_6yrs']) + '-1'
y, X = patsy.dmatrices(f, data=couple_data, return_type='dataframe')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1647 entries, 33536 to 4621371
# Data columns (total 62 columns):
# pphouse[a building with 2 or more apartments]                                   1647 non-null float64
# pphouse[a mobile home]                                                          1647 non-null float64
# pphouse[a one-family house attached to one or more houses]                      1647 non-null float64
# pphouse[a one-family house detached from any other house]                       1647 non-null float64
# hhinc[T.low_hhinc]                                                              1647 non-null float64
# pprent[T.rented for cash]                                                       1647 non-null float64
# higher_income_earner[T.female_earn_more]                                        1647 non-null float64
# higher_income_earner[T.male_earn_more]                                          1647 non-null float64
# same_high_school[T.same high school]                                            1647 non-null float64
# same_college_uni[T.did not attend same college or university]                   1647 non-null float64
# grow_up_same_city_town[T.yes]                                                   1647 non-null float64
# parent_alive[T.father only]                                                     1647 non-null float64
# parent_alive[T.mother only]                                                     1647 non-null float64
# parent_alive[T.neither father nor mother are alive]                             1647 non-null float64
# met_partner_work[T.yes]                                                         1647 non-null float64
# friend_intro_partner[T.yes]                                                     1647 non-null float64
# self_intro_partner[T.yes]                                                       1647 non-null float64
# q24_met_online[T.met online]                                                    1647 non-null float64
# q24_school[T.Yes]                                                               1647 non-null float64
# q24_bar_restaurant[T.Yes]                                                       1647 non-null float64
# q24_private_party[T.Yes]                                                        1647 non-null float64
# same_sex_couple[T.same-sex couple]                                              1647 non-null float64
# met_through_friends[T.meet through friends]                                     1647 non-null float64
# met_through_family[T.met through family]                                        1647 non-null float64
# married[T.married]                                                              1647 non-null float64
# parental_approval[T.approve]                                                    1647 non-null float64
# couple_politic_view_comb[T.democrat_other]                                      1647 non-null float64
# couple_politic_view_comb[T.democrat_republican]                                 1647 non-null float64
# couple_politic_view_comb[T.other_other]                                         1647 non-null float64
# couple_politic_view_comb[T.republican_other]                                    1647 non-null float64
# couple_politic_view_comb[T.republican_republican]                               1647 non-null float64
# couple_evang_comb[T.no_evang or born again]                                     1647 non-null float64
# couple_evang_comb[T.no_no]                                                      1647 non-null float64
# couple_relig_comb[T.Catholic_other]                                             1647 non-null float64
# couple_relig_comb[T.Protestant or oth Christian_Catholic]                       1647 non-null float64
# couple_relig_comb[T.Protestant or oth Christian_Protestant or oth Christian]    1647 non-null float64
# couple_relig_comb[T.Protestant or oth Christian_other]                          1647 non-null float64
# couple_relig_comb[T.other_other]                                                1647 non-null float64
# couple_race_comb[T.NH white_other]                                              1647 non-null float64
# couple_race_comb[T.other_other]                                                 1647 non-null float64
# gender_work_status[T.employee_male]                                             1647 non-null float64
# gender_work_status[T.not-working_female]                                        1647 non-null float64
# gender_work_status[T.not-working_male]                                          1647 non-null float64
# gender_work_status[T.self-employed_female]                                      1647 non-null float64
# gender_work_status[T.self-employed_male]                                        1647 non-null float64
# gender_internet_access[T.no_male]                                               1647 non-null float64
# gender_internet_access[T.yes_female]                                            1647 non-null float64
# gender_internet_access[T.yes_male]                                              1647 non-null float64
# hhhead_gender[T.yes_male]                                                       1647 non-null float64
# marriage_count_gender[T.married before_male]                                    1647 non-null float64
# marriage_count_gender[T.never married_female]                                   1647 non-null float64
# marriage_count_gender[T.never married_male]                                     1647 non-null float64
# relatives_seen_per_month                                                        1647 non-null float64
# distancemoved_10mi                                                              1647 non-null float64
# how_long_ago_first_met                                                          1647 non-null float64
# how_long_ago_first_romantic                                                     1647 non-null float64
# how_long_ago_first_cohab                                                        1647 non-null float64
# how_long_relationship                                                           1647 non-null float64
# age_difference                                                                  1647 non-null float64
# met_through_as_coworkers                                                        1647 non-null float64
# couple_yrsed_diff                                                               1647 non-null float64
# couple_moms_yrsed_diff                                                          1647 non-null float64
# dtypes: float64(62)
# memory usage: 810.6+ KB

# %%
X.to_pickle('./couple_data_without_resample_predictors')
y.to_pickle('./couple_data_without_resample_target')

# %%
y_orig = y

# %%
y = y.values.ravel()

# %%
# Resample using SMOTE + Tomek
from imblearn.combine import SMOTETomek
smtomek = SMOTETomek(random_state=42)
X_st, y_st = smtomek.fit_sample(X, y)

# %%
X_st_df = pd.DataFrame(X_st, columns=[col for col in X.columns])
y_st_df = pd.DataFrame(y_st, columns=['relationship_outcome_6yrs'])
# make sure dummy columns for categorical values are all 0/1
for cat_col in couple_data_cat.columns:
    for dum_col in X_st_df.columns:
        if dum_col.find(cat_col) >= 0:
            X_st_df[dum_col] = X_st_df[dum_col].astype('int64')

# %%
X_st_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2194 entries, 0 to 2193
# Data columns (total 62 columns):
# pphouse[a building with 2 or more apartments]                                   2194 non-null int64
# pphouse[a mobile home]                                                          2194 non-null int64
# pphouse[a one-family house attached to one or more houses]                      2194 non-null int64
# pphouse[a one-family house detached from any other house]                       2194 non-null int64
# hhinc[T.low_hhinc]                                                              2194 non-null int64
# pprent[T.rented for cash]                                                       2194 non-null int64
# higher_income_earner[T.female_earn_more]                                        2194 non-null int64
# higher_income_earner[T.male_earn_more]                                          2194 non-null int64
# same_high_school[T.same high school]                                            2194 non-null int64
# same_college_uni[T.did not attend same college or university]                   2194 non-null int64
# grow_up_same_city_town[T.yes]                                                   2194 non-null int64
# parent_alive[T.father only]                                                     2194 non-null int64
# parent_alive[T.mother only]                                                     2194 non-null int64
# parent_alive[T.neither father nor mother are alive]                             2194 non-null int64
# met_partner_work[T.yes]                                                         2194 non-null int64
# friend_intro_partner[T.yes]                                                     2194 non-null int64
# self_intro_partner[T.yes]                                                       2194 non-null int64
# q24_met_online[T.met online]                                                    2194 non-null int64
# q24_school[T.Yes]                                                               2194 non-null int64
# q24_bar_restaurant[T.Yes]                                                       2194 non-null int64
# q24_private_party[T.Yes]                                                        2194 non-null int64
# same_sex_couple[T.same-sex couple]                                              2194 non-null int64
# met_through_friends[T.meet through friends]                                     2194 non-null int64
# met_through_family[T.met through family]                                        2194 non-null int64
# married[T.married]                                                              2194 non-null int64
# parental_approval[T.approve]                                                    2194 non-null int64
# couple_politic_view_comb[T.democrat_other]                                      2194 non-null int64
# couple_politic_view_comb[T.democrat_republican]                                 2194 non-null int64
# couple_politic_view_comb[T.other_other]                                         2194 non-null int64
# couple_politic_view_comb[T.republican_other]                                    2194 non-null int64
# couple_politic_view_comb[T.republican_republican]                               2194 non-null int64
# couple_evang_comb[T.no_evang or born again]                                     2194 non-null int64
# couple_evang_comb[T.no_no]                                                      2194 non-null int64
# couple_relig_comb[T.Catholic_other]                                             2194 non-null int64
# couple_relig_comb[T.Protestant or oth Christian_Catholic]                       2194 non-null int64
# couple_relig_comb[T.Protestant or oth Christian_Protestant or oth Christian]    2194 non-null int64
# couple_relig_comb[T.Protestant or oth Christian_other]                          2194 non-null int64
# couple_relig_comb[T.other_other]                                                2194 non-null int64
# couple_race_comb[T.NH white_other]                                              2194 non-null int64
# couple_race_comb[T.other_other]                                                 2194 non-null int64
# gender_work_status[T.employee_male]                                             2194 non-null int64
# gender_work_status[T.not-working_female]                                        2194 non-null int64
# gender_work_status[T.not-working_male]                                          2194 non-null int64
# gender_work_status[T.self-employed_female]                                      2194 non-null int64
# gender_work_status[T.self-employed_male]                                        2194 non-null int64
# gender_internet_access[T.no_male]                                               2194 non-null int64
# gender_internet_access[T.yes_female]                                            2194 non-null int64
# gender_internet_access[T.yes_male]                                              2194 non-null int64
# hhhead_gender[T.yes_male]                                                       2194 non-null int64
# marriage_count_gender[T.married before_male]                                    2194 non-null int64
# marriage_count_gender[T.never married_female]                                   2194 non-null int64
# marriage_count_gender[T.never married_male]                                     2194 non-null int64
# relatives_seen_per_month                                                        2194 non-null float64
# distancemoved_10mi                                                              2194 non-null float64
# how_long_ago_first_met                                                          2194 non-null float64
# how_long_ago_first_romantic                                                     2194 non-null float64
# how_long_ago_first_cohab                                                        2194 non-null float64
# how_long_relationship                                                           2194 non-null float64
# age_difference                                                                  2194 non-null float64
# met_through_as_coworkers                                                        2194 non-null float64
# couple_yrsed_diff                                                               2194 non-null float64
# couple_moms_yrsed_diff                                                          2194 non-null float64
# dtypes: float64(10), int64(52)
# memory usage: 1.0 MB

# %%
X_st_df[['higher_income_earner[T.female_earn_more]']] = X_st_df[['higher_income_earner[T.female_earn_more]']].astype('int64')
X_st_df.age_difference = X_st_df.age_difference.astype('int64')
X_st_df.respondent_yrsed = X_st_df.respondent_yrsed.astype('int64')
X_st_df.partner_yrsed = X_st_df.partner_yrsed.astype('int64')
X_st_df.partner_mom_yrsed = X_st_df.partner_mom_yrsed.astype('int64')
X_st_df.respondent_mom_yrsed = X_st_df.respondent_mom_yrsed.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-cdd309588b76> in <module>()
#       1 X_st_df[['higher_income_earner[T.female_earn_more]']] = X_st_df[['higher_income_earner[T.female_earn_more]']].astype('int64')
#       2 X_st_df.age_difference = X_st_df.age_difference.astype('int64')
# ----> 3 X_st_df.respondent_yrsed = X_st_df.respondent_yrsed.astype('int64')
#       4 X_st_df.partner_yrsed = X_st_df.partner_yrsed.astype('int64')
#       5 X_st_df.partner_mom_yrsed = X_st_df.partner_mom_yrsed.astype('int64')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'respondent_yrsed'

# %%
X_st_df.describe()

# %%
X_st_df.to_pickle('./couple_data_predictors')
y_st_df.to_pickle('./couple_data_target')

# %%
y_st_df.relationship_outcome_6yrs.value_counts()

# %%
y_orig.relationship_outcome_6yrs.value_counts()
503/float(1144)

# %%
# Get reverse imbalance dataset
merge_df = pd.concat([X_st_df,y_st_df],axis=1)
sub_df = merge_df[merge_df.relationship_outcome_6yrs == 0]
us_df = sub_df.sample(frac=0.44, random_state=42)
remerge_df = pd.concat([merge_df[merge_df.relationship_outcome_6yrs == 1], us_df], axis=0)

# %%
remerge_df.drop(labels=['relationship_outcome_6yrs'],axis=1).to_pickle('./couple_data_rev_imbal_predictors')
remerge_df.relationship_outcome_6yrs.to_pickle('./couple_data_rev_imbal_target')
