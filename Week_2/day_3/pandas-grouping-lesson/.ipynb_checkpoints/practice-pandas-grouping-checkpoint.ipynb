# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Practice Grouping Data with Pandas
#
# _Authors: Kiefer Katovich (SF), Dave Yerrington (SF), Mario Carrillo (SF)_
#
# ---
#
# You are going to investigate UFO sightings around the US.  This lab will give you practice performing `groupby` operations to split data along multiple dimensions and investigate patterns between subsets of the data using basic aggregation.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# #### 1. Load and print the header for the UFO data.

# %%
ufo_csv = 'datasets/ufo.csv'

# %%
# A:
ufo_df = pd.read_csv(ufo_csv)
ufo_df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# #### 2. How many null values exist per column?

# %%
# A:
ufo_df.isnull().sum()
# Out:
# City                  47
# Colors Reported    63509
# Shape Reported      8402
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# #### 3. Which city has the most observations?

# %%
# A:
ufo_df.groupby(['City']).size().sort_values(ascending=False)
# Out:
# City
# Seattle                       646
# New York City                 612
# Phoenix                       533
# Las Vegas                     442
# Portland                      438
# Los Angeles                   416
# San Diego                     401
# Houston                       340
# Chicago                       337
# Miami                         279
# Tucson                        278
# Orlando                       264
# Austin                        254
# Springfield                   246
# Albuquerque                   244
# Columbus                      235
# Sacramento                    232
# Denver                        219
# San Francisco                 216
# San Jose                      212
# Jacksonville                  203
# Myrtle Beach                  201
# San Antonio                   201
# Dallas                        195
# Salem                         182
# St. Louis                     175
# Charlotte                     174
# Columbia                      169
# Mesa                          165
# Louisville                    163
#                              ...
# Middle Smithfield Township      1
# Middle Town                     1
# Middle Valley                   1
# Middle Village                  1
# Middleborough                   1
# Middleburg HTS                  1
# Middleburg Hts.                 1
# Middlesex Township              1
# Midway City                     1
# Mifflinburg                     1
# Mifflintown                     1
# Mifflinville                    1
# Milaca                          1
# Mile 69                         1
# Milligan                        1
# Mile Marker 120                 1
# Milford Township                1
# Mill Hall                       1
# MillHeim                        1
# Milladore                       1
# Millard                         1
# Millbury                        1
# Millcreek                       1
# Miller                          1
# Millers                         1
# Millers Falls                   1
# Millerstown                     1
# Millersvill                     1
# Millhurst                       1
# ((HOAX??))                      1
# Length: 13504, dtype: int64

# %% [markdown]
# #### 4. What is the observation count per shape?

# %%
# A:
ufo_df.groupby(['Shape Reported']).size().sort_values(ascending=False)
# Out:
# Shape Reported
# LIGHT        16332
# TRIANGLE      7816
# CIRCLE        7725
# FIREBALL      6249
# OTHER         5506
# SPHERE        5231
# DISK          5226
# OVAL          3721
# FORMATION     2405
# CIGAR         1983
# VARIOUS       1957
# FLASH         1329
# RECTANGLE     1295
# CYLINDER      1252
# DIAMOND       1152
# CHEVRON        940
# EGG            733
# TEARDROP       723
# CONE           310
# CROSS          241
# DELTA            7
# CRESCENT         2
# ROUND            2
# DOME             1
# HEXAGON          1
# PYRAMID          1
# FLARE            1
# dtype: int64

# %% [markdown]
# #### 5. Create a subset of the data that is the top 5 cities and the top 5 shapes.

# %%
# A:

top_5 = dict(ufo_df.groupby(['City', 'Shape Reported']).size().sort_values(ascending=False).head(5))

for index, row in ufo_df.iterrows(): 
    # print the name of city and Shape as tuple
    print(row['City'], row['Shape Reported'])
    # print the data of that regiment
    #print(group)
# Out:
# ('Ithaca', 'TRIANGLE')
# ('Willingboro', 'OTHER')
# ('Holyoke', 'OVAL')
# ('Abilene', 'DISK')
# ('New York Worlds Fair', 'LIGHT')
# ('Valley City', 'DISK')
# ('Crater Lake', 'CIRCLE')
# ('Alma', 'DISK')
# ('Eklutna', 'CIGAR')
# ('Hubbard', 'CYLINDER')
# ('Fontana', 'LIGHT')
# ('Waterloo', 'FIREBALL')
# ('Belton', 'SPHERE')
# ('Keokuk', 'OVAL')
# ('Ludington', 'DISK')
# ('Forest Home', 'CIRCLE')
# ('Los Angeles', nan)
# ('Hapeville', nan)
# ('Oneida', 'RECTANGLE')
# ('Bering Sea', 'OTHER')
# ('Nebraska', 'DISK')
# (nan, nan)
# (nan, 'LIGHT')
# ('Owensboro', 'RECTANGLE')
# ('Wilderness', 'DISK')
# ('San Diego', 'CIGAR')
# ('Wilderness', 'DISK')
# ('Clovis', 'DISK')
# ('Los Alamos', 'DISK')
# ('Ft. Duschene', 'DISK')
# ('South Kingstown', 'SPHERE')
# ('North Tampa', 'CYLINDER')
# ('Ft. Lee', 'CIGAR')
# ('Salinas AFB', 'DISK')
# ('Jasper', 'FIREBALL')
# ('Winston-Salem', 'DISK')
# ('Portsmouth', 'FORMATION')
# ('Dallas', 'SPHERE')
# ('Huntington Beach', 'DISK')
# ('San Antonio', 'OVAL')
# ('Roswell', 'SPHERE')
# ('New York City', 'DISK')
# ('Merced', 'SPHERE')
# ('Alice', 'DISK')
# ('Blairsden', 'SPHERE')
# ('Index', 'FIREBALL')
# ('South Portland', 'OVAL')
# ('Oak Lawn', 'FORMATION')
# ('Dome', 'FLASH')
# ('Conroe', 'OTHER')
# ('Syracuse', 'DISK')
# ('Miami', 'OTHER')
# ('San Deigo', 'TRIANGLE')
# ('Minden', nan)
# ('Cleveland', 'LIGHT')
# ('Espanola', 'CIRCLE')
# ('Oroville', nan)
# ('Oakmont', nan)
# ('Winona', 'DISK')
# ('Gackle', 'OTHER')
# ('Madison', 'DISK')
# ('Hayward', 'CIRCLE')
# ('Tacoma', 'OTHER')
# ('Baltimore', 'OVAL')
# ('Cashmere', 'FORMATION')
# ('Maywood', 'DISK')
# ('Wexford', nan)
# ('Sioux Falls', nan)
# ('Seattle', 'OVAL')
# ('Dell Rapids', nan)
# ('Philadelphia', 'DISK')
# ('Roswell', nan)
# ('Johnston City', 'DISK')
# ('Roswell', nan)
# ('Syracuse', 'CIGAR')
# ('Richmond', 'CIRCLE')
# ('Las Vegas', 'DISK')
# ('Keeneyville', 'FORMATION')
# ('Clintwood', 'CYLINDER')
# ('Hazelton', 'DISK')
# ('Minneapolis', 'DISK')
# ('Morehouse', 'CYLINDER')
# ('San Jose', 'CHEVRON')
# ('Raton', 'OVAL')
# ('Modesto', 'DISK')
# ('Green Valley', nan)
# ('Henrietta', 'LIGHT')
# ('Saranac Lake', 'DISK')
# ('Proctor', 'CIGAR')
# ('Whitmore Lake', 'CIGAR')
# ('Kelseyville', 'DISK')
# ('Scipio', 'SPHERE')
# ('Borger', 'DISK')
# ('Baltimore', 'OVAL')
# ('Jim Ridge', nan)
# ('Ojai', 'LIGHT')
# ('New York City', 'CIRCLE')
# ('Conshohocken', 'OVAL')
# ('Sharpsburg', 'CIRCLE')
# ('Seattle', 'DISK')
# ('Oak Ridge', 'OTHER')
# ('Grays', 'LIGHT')
# ('Los Angeles', 'CIRCLE')
# ('Anchorage', 'DISK')
# ('Knoxville', 'OTHER')
# ('Salem', 'CIGAR')
# ('Fairbanks', 'DISK')
# ('Marion', 'FORMATION')
# ('Booneville', nan)
# ('Excelsior', 'CIRCLE')
# ('Mill Valley', 'LIGHT')
# ('Tarrant City', 'CIRCLE')
# ('Steilacoom', 'DISK')
# ('Mt Gilead', 'CIRCLE')
# ('Post', 'DISK')
# ('San Marcos', 'CYLINDER')
# ('Lackland AFB', 'LIGHT')
# ('Baltimore', 'CIGAR')
# ('Mount Hope', nan)
# ('New York City', 'OVAL')
# ('Roswell', nan)
# ('Arkansas', 'DISK')
# ('Waynesborough', 'DISK')
# ('Fort Lewis', 'TRIANGLE')
# ('Crowder', nan)
# ('Philadelphia', 'DISK')
# ('Pittsburgh', 'OVAL')
# ('Kensington', 'OVAL')
# ('Kansas City', 'DISK')
# ('Napa', 'DISK')
# ('Grosse Pointe Park', 'OVAL')
# ('Bonifay', 'DISK')
# ('Fort Worth', 'DISK')
# ('Booneville', 'DISK')
# ('Galveston', 'SPHERE')
# ('Lac Du Flambeau', 'DISK')
# ('Florence', 'DISK')
# ('Florence', 'LIGHT')
# ("Coeur d'Alene", 'CIGAR')
# ('Bay St. Louis', 'LIGHT')
# ('East Palestine', 'LIGHT')
# ('Newark', 'SPHERE')
# ('Los Padres National Forest', 'FORMATION')
# ('Smithport', 'DISK')
# ('Louisville', 'OTHER')
# ('Stanfield', 'DISK')
# ('Pikeville', 'DISK')
# ('Sandy Hook', 'TRIANGLE')
# ('Half Moon Bay', 'OTHER')
# ('Palm Springs', 'CIGAR')
# ('Thompsonville', 'DISK')
# ('Los Angeles', 'DISK')
# ('Irving', 'DISK')
# ('Fort Sill', 'OVAL')
# ('Oklahoma', 'CIGAR')
# ('Jasper', 'OVAL')
# ('Mount Pinos', 'DISK')
# ('Greenville', 'DISK')
# ('Jackson Heights', 'DISK')
# ('Birmingham', nan)
# ('Otis Orchards', 'DISK')
# ('Atlanta', nan)
# ('Calaveras County', 'DISK')
# ('Green River', 'SPHERE')
# ('Provo', 'DISK')
# ('Spokane Valley', 'SPHERE')
# ('Sunland', 'CIRCLE')
# ('Altoona', 'DISK')
# ('Jacksonville', 'DISK')
# ('Holloman AFB', 'CIRCLE')
# ('Salt Lake City', nan)
# ('Binghamton', 'DISK')
# ('Nellis AFB', 'DISK')
# ('Chicago', 'DISK')
# ('Greenville', 'TRIANGLE')
# ('Pittsburgh', 'CYLINDER')
# ('Allyn', 'DISK')
# ('Dousman', nan)
# ('Norfolk', 'FIREBALL')
# ('Evergreen', 'DISK')
# ('Chicago', 'CIRCLE')
# ('Fortville', 'DISK')
# ('Luke Airforce Base', 'EGG')
# ('Piedra Blanka', 'CIGAR')
# ('Jacksonville', 'TRIANGLE')
# ('Maywood', 'CIRCLE')
# ('Lansing', 'OTHER')
# ('Chester', 'OVAL')
# ('Cheyenne', 'DISK')
# ('Pecos', 'DISK')
# ('Barksdale AFB', nan)
# ('Miami', 'LIGHT')
# ('New York City', 'DISK')
# ('Auburn', 'OVAL')
# ('Miami', 'DISK')
# ('Miami', 'DISK')
# ('Miami', 'LIGHT')
# ('Sebeka', 'OTHER')
# ('Detroit', 'SPHERE')
# ('Tacoma', 'SPHERE')
# ('Evergreen', 'CIRCLE')
# ('Arlington', 'DISK')
# ('Arlington', 'OVAL')
# ('Wilmington', 'DISK')
# (nan, 'DISK')
# ('Litchfield', 'OTHER')
# ('South Gate', 'CIRCLE')
# ('North Bend', 'OTHER')
# ('New York City', 'OTHER')
# ('Okolona', 'OVAL')
# ('Tacoma', 'SPHERE')
# ('Manville', 'SPHERE')
# ('Tampa', 'OVAL')
# ("Smithson's Valley", 'CIGAR')
# ('Prairie Grove', 'DISK')
# ('Hamilton', 'LIGHT')
# ('Philadelphia', 'CIRCLE')
# ('Norridgewock', 'DISK')
# ('Kansas City', 'DISK')
# ('Richland', 'CIRCLE')
# ('Chicago', 'OTHER')
# ('Camp McCoy', 'CYLINDER')
# ('Nebraska', nan)
# ('Oklahoma', 'CIGAR')
# ('Palm Springs', nan)
# ('Haverhill', 'CHEVRON')
# ('Cambridge', 'SPHERE')
# ('Chariton', 'OTHER')
# ('Los Angeles', 'FIREBALL')
# ('Midwest City', 'FIREBALL')
# ('Jamison', 'CIGAR')
# ('Kingman', nan)
# ('Fresno', nan)
# ('Roswell', nan)
# ('Wenatchee', 'DISK')
# ('Fort Worth', 'SPHERE')
# ('North Bend', 'CIRCLE')
# ('Galveston', 'CIGAR')
# ('Cleveland', 'FIREBALL')
# ('Kelso', 'OVAL')
# ('Colorado Springs', 'DISK')
# (nan, 'DISK')
# ('Ogallala', 'OTHER')
# ('Nashville', 'CYLINDER')
# ('Dublin', 'CONE')
# ('Berkeley', 'FIREBALL')
# ('San Bernadino Mtns, Church Camp', 'DISK')
# ('Vallejo', 'LIGHT')
# ('Louisville', 'CIRCLE')
# ('Artesia', 'OTHER')
# ('Bowleys Quarters', 'SPHERE')
# ('Homer', nan)
# ('Mauriceville', 'DISK')
# ('New Orleans', 'OVAL')
# ('Cicero', 'OTHER')
# ('Keansburg', 'CIRCLE')
# ('Pendleton', 'DISK')
# ('Lackland Air Force Base', 'DISK')
# ('Brunswick', nan)
# ('Lakeland', 'DISK')
# ('Souix City', 'CIRCLE')
# ('Santa Monica', 'LIGHT')
# ('Fairbanks', nan)
# ('Burney', 'DISK')
# ('Stanford Campus', 'DISK')
# ('Corvallis', 'DIAMOND')
# ('Quincy', 'DISK')
# ('Houston', 'DISK')
# ('Ovid', 'DISK')
# ('Springfield', 'CYLINDER')
# ('El Cerrito', 'LIGHT')
# ('Toledo', 'DISK')
# ('Norfolk', 'DISK')
# ('Philadelphia', 'DISK')
# ('Fish Canyon', 'LIGHT')
# ('Atlanta', 'DISK')
# ('Estes Park', 'CIGAR')
# ('Glenburn', nan)
# ('Palm Beach', 'LIGHT')
# ('Claymont', 'DISK')
# ('Ellington AFB', 'DISK')
# ('Lorton', 'OTHER')
# ('Langley Air Force Base', 'CIRCLE')
# ('Thrifty', 'CIRCLE')
# ('Marion', 'CIRCLE')
# ('Methuen', nan)
# ('Hawthorne', 'LIGHT')
# ('Pasadena', 'CIRCLE')
# ('St. Louis Airport', 'OVAL')
# ('Los Angeles', 'CIRCLE')
# ('Walnut Creek', nan)
# ('West Columbia', 'FORMATION')
# ('Morroco', 'VARIOUS')
# ('Philadelphia', 'DISK')
# ('Greenfield', 'CIGAR')
# ('Kansas City', 'CHEVRON')
# ('Oakdale', 'DISK')
# ('Bridge Hampton', 'LIGHT')
# ('Farmingdale', 'OVAL')
# ('Dyer', 'TRIANGLE')
# ('Canton', 'DISK')
# ('North Hollywood', 'LIGHT')
# ('Puyallup', 'OVAL')
# ('Geneva', 'DISK')
# ('Beaumont', 'DISK')
# ('Palmer Township', 'OTHER')
# ('Flatwoods', 'CIRCLE')
# ('Blanco', 'OTHER')
# ('Manistee', 'CIRCLE')
# ('Denver', 'FIREBALL')
# ('Thelma', 'DISK')
# ('Red Bank', 'CIRCLE')
# ('Yucaipa', 'OVAL')
# ('New York City', 'LIGHT')
# ('Holbrook', 'EGG')
# ('Warrington', 'FIREBALL')
# ('Homaland', 'CIRCLE')
# ('Bagley', 'CIRCLE')
# ('Cincinnati', 'DISK')
# ('Martinez', 'CIRCLE')
# ('Clinton', 'EGG')
# ('Pensacola', 'LIGHT')
# ('South St. Paul', 'DISK')
# ('Terre Haute', 'CIRCLE')
# ('Missouri', 'LIGHT')
# ('Youngstown', nan)
# ('Daytona Beach', 'FIREBALL')
# ('Rantoul', 'LIGHT')
# ('Beach Haven Park', 'DISK')
# ('Quartz Hill', 'DISK')
# ('Lubbock', 'CIGAR')
# ('Dumas', 'LIGHT')
# ('Morehead City', 'DISK')
# ('Carnation', 'DISK')
# ('Dierks', 'CIGAR')
# ('Woodland Park', 'OVAL')
# ('Ringold', 'LIGHT')
# ('Newtown Square', 'CIRCLE')
# ('Independence', 'FIREBALL')
# ('Madisonville', 'LIGHT')
# ('Eagle Pass', 'CIGAR')
# ('Covina', 'DISK')
# ('Bullhead', 'DISK')
# ('Mono Lake', 'CIRCLE')
# ('West Covina', nan)
# ('Rhinebeck', 'LIGHT')
# ('Weirton', 'DISK')
# ('Petaluma', 'OVAL')
# ('Bowie', 'DISK')
# ('Hampton', 'SPHERE')
# ('Canton', 'CIGAR')
# ('Pine castle AFB', 'LIGHT')
# ('Ada', 'CIRCLE')
# ('Belton', 'OTHER')
# ('Memphis', 'CYLINDER')
# ('Elmore', 'SPHERE')
# ('Salt Lake City', 'CIRCLE')
# ('Upper Glade', 'EGG')
# ('Akron', 'OTHER')
# ('Edroy', nan)
# ('San Francisco', 'OTHER')
# ('Palo Alto', 'FIREBALL')
# ('Richfield Springs', 'CIGAR')
# ('Vista', 'CIGAR')
# ('Farragut', 'CIGAR')
# ('Tulsa', 'FLASH')
# ('Salem', 'DISK')
# ('New York City', 'LIGHT')
# ('Cincinnati', 'DISK')
# ('Madera', 'SPHERE')
# ('Willow Grove', 'LIGHT')
# ('Cape Girardeau', 'DIAMOND')
# ('New Brunswick', 'DISK')
# ('Houston', 'TRIANGLE')
# ('Beatrice', 'OTHER')
# ('Wichita', nan)
# ('Sacramento', 'DISK')
# ('East Hampton', 'DISK')
# ('Yellowstone Park', 'DISK')
# ('Sugarcreek', 'DISK')
# ('Harvard', nan)
# ('Bradford', 'SPHERE')
# ('Norfolk', 'CIGAR')
# ('Middle River', 'CIRCLE')
# ('Hope', 'CIRCLE')
# ('Greenwich', 'LIGHT')
# ('Newport', 'RECTANGLE')
# ('Edna', 'CIRCLE')
# ('Mt. Vernon', 'DISK')
# ('Aberdeen', 'CIRCLE')
# ('Painsville', 'RECTANGLE')
# ('Columbus', 'FORMATION')
# ('Dallas', nan)
# ('Jena', 'SPHERE')
# ('Fort Devans', 'OVAL')
# ('Los Angeles', 'FORMATION')
# ('Los Angeles', 'DISK')
# ('Canton', 'CIGAR')
# ('Rhinebeck', 'DIAMOND')
# ('Union Bower are irving', 'FORMATION')
# ('El Paso', 'DISK')
# ('E. Los Angeles', 'LIGHT')
# ('Glens Falls', 'DISK')
# ('Irving', 'LIGHT')
# ('Hicksville', 'CIRCLE')
# ('Green Lake', 'OVAL')
# ('Livermore Falls', 'DIAMOND')
# ('Great Falls', nan)
# ('Hartford City', 'DISK')
# ('Walled Lake', 'CYLINDER')
# ('San Leandro', 'LIGHT')
# ('Lubbock', 'TRIANGLE')
# ('Norwalk', 'DISK')
# ('Arctic', 'CIGAR')
# ('Dallas', 'OTHER')
# ('Birmingham', nan)
# ('New York City', 'TEARDROP')
# ('Burlington', 'CIRCLE')
# ('Russellville', 'SPHERE')
# ('Barker', 'DISK')
# ('Albany', 'CIRCLE')
# ('Mullens', 'OVAL')
# ('Talcott', 'SPHERE')
# ('Del Rio', 'CIGAR')
# ('Phillipsburg', 'CIGAR')
# ('Baltimore', 'OTHER')
# ('Chesapeake', 'DISK')
# ('Temple City', 'LIGHT')
# ('Houston', 'DIAMOND')
# ('Williamsport', 'CIGAR')
# ('Long Beach', 'DISK')
# ('Denver', 'LIGHT')
# ('Kresgeville', nan)
# ('Salt  Lake City', 'DISK')
# ('Kansas City', 'LIGHT')
# ('Arco', 'DISK')
# ('Vandalia', 'DISK')
# ('Bainbridge', 'FIREBALL')
# ('Indianapolis', 'LIGHT')
# ('San Diego', 'DISK')
# ('Ticonderoga', 'DISK')
# ('California', 'FIREBALL')
# ('Longview', 'TRIANGLE')
# ('Ludlow', 'CIGAR')
# ('Exeter', 'DISK')
# ('Auburn', nan)
# ("Smith's Ferry", 'DISK')
# ('Huntington', 'TRIANGLE')
# ('Graham', 'SPHERE')
# ('Brecksville', 'CIRCLE')
# ('Los Gatos', 'DISK')
# ('St. Paul', 'DISK')
# ('El Paso', 'DISK')
# ('Lake Jackson', 'FIREBALL')
# ('Tacoma', 'DISK')
# ('Hopkinsville', 'CIGAR')
# ('Nelchina', nan)
# ('Martelle', 'CIGAR')
# ('Paterson', 'DISK')
# ('Northeast Cape AFS', nan)
# ('St. Paul', 'LIGHT')
# ('England', 'DISK')
# ('New York City', nan)
# ('Houston', 'LIGHT')
# ('Commerce City', 'FIREBALL')
# ('Teaneck', 'CYLINDER')
# ('Corpus Christi', 'LIGHT')
# ('St Lawrence Island', 'OTHER')
# ('Madison', 'CIGAR')
# ('Madison', 'CIGAR')
# ('Pep', 'FIREBALL')
# ('Howell', 'CIGAR')
# ('Winooski', 'OVAL')
# ('Winooski', 'OVAL')
# ('Palmer Park', 'SPHERE')
# ('North Hollywood', 'CIRCLE')
# ('Cincinnati', 'DIAMOND')
# ('North Hollywood', 'SPHERE')
# ('Middlesex', 'CIRCLE')
# ('San Francisco', 'OVAL')
# ('New York City', 'OVAL')
# ('Timpson', 'LIGHT')
# ('Grand Island', 'CIRCLE')
# ('Cincinnati', 'DIAMOND')
# ('Baldwin Park', 'CIGAR')
# ('Florala ?', 'DISK')
# ('Mountain View', 'OTHER')
# ('Coffeyville', 'CIGAR')
# ('Yonkers', 'LIGHT')
# ('Menlo Park', 'LIGHT')
# ('Houston', 'DISK')
# ('Oklahoma', 'LIGHT')
# ('Pawnee', nan)
# ('Pawnee', 'LIGHT')
# ('Silverdale', 'CYLINDER')
# ('Conyers', 'TEARDROP')
# ('Camden', 'DISK')
# ('Fort Worth', 'DISK')
# ('Durham', 'LIGHT')
# ('Thibodaux', 'FIREBALL')
# ('Osmond', nan)
# ('Muncie', nan)
# ('Cheektowaga', 'TEARDROP')
# ('Woodland Hills', 'LIGHT')
# ('no data', 'DISK')
# ('Novato', 'DISK')
# ('Rock Springs', 'DISK')
# ('Randallstown', 'TRIANGLE')
# ('Derby', 'DISK')
# ('Scarborough', 'DISK')
# ('Bellevue', 'LIGHT')
# ('Monroe', 'OVAL')
# ('Fargo', 'DISK')
# ('Perry', 'TRIANGLE')
# ('Arthur', nan)
# ('Ashland', 'CIRCLE')
# ('Davis Jct.', 'FIREBALL')
# ('Phelps County', 'DISK')
# ('St. Paul', 'OTHER')
# ('Terrebonne', nan)
# ('Riverside', 'LIGHT')
# ('Greenville', 'DISK')
# ('Milwaukee', 'DISK')
# ('South San Francisco', 'DISK')
# ('New York City', nan)
# ('Miami', 'SPHERE')
# ('Mendham', 'DISK')
# ('Baden', 'CYLINDER')
# ('Columbus', 'LIGHT')
# ('El Sobrante', 'CIRCLE')
# ('Evanston', nan)
# ('Cincinnati', 'DISK')
# ('Wabash River', 'CIRCLE')
# ('Nashville', nan)
# ('Orange', 'CYLINDER')
# ('Sidney', 'LIGHT')
# ('Nelson', 'CIGAR')
# ('Arvada', 'CIRCLE')
# ('Monroe', nan)
# ('Missoula', nan)
# ('Minneapolis', 'OTHER')
# ('Campbell', 'DISK')
# ('Buffalo', 'LIGHT')
# ('Minneapolis', 'FORMATION')
# ('Globe', 'RECTANGLE')
# ('Campbellsport', 'CIRCLE')
# ('New York City', 'OVAL')
# ('Phoenix', 'DISK')
# ('Strathmore', 'DISK')
# ('Castle Rock', 'CIGAR')
# ('Gardner Lake', 'OVAL')
# ('Long Beach', 'LIGHT')
# ('Nort Sutton', nan)
# ('New Albany', 'CIGAR')
# ('Worcester', 'OTHER')
# ('Salem', 'DISK')
# ('Fort Lauderdale', 'LIGHT')
# ('Allendale', 'LIGHT')
# ('Golden', 'DISK')
# ('Reseda', 'DISK')
# ('Troy', nan)
# ('Jewett', 'LIGHT')
# ('Roswell', nan)
# ('Mohave', 'LIGHT')
# ('Lake Bonita', 'FIREBALL')
# ('Fallon', 'OVAL')
# ('Goldfield', 'LIGHT')
# ('Dayton', 'DISK')
# ('New York City', 'OTHER')
# ('Jacksonville', nan)
# ('Duluth', nan)
# ('Duluth', nan)
# ('Rock Hill', 'TRIANGLE')
# ('Marysville', 'OTHER')
# ('Four States', 'SPHERE')
# ('Starke', 'SPHERE')
# ('Lafayette', 'CIRCLE')
# ('Los Angeles', 'DISK')
# ('Tehachapi', 'FIREBALL')
# ('Del Mar', nan)
# ('Bristol', 'DISK')
# ('St. Paul', 'CIGAR')
# ('Hartwell', 'CIGAR')
# ('Winston-Salem', 'CIGAR')
# ('Houston', 'TRIANGLE')
# ('Houston', 'OTHER')
# ('Tucson', 'LIGHT')
# ('Schenectady', nan)
# ('Terre Haute', 'OTHER')
# ('Great Bend', 'OTHER')
# ('Salt Lake City', 'DISK')
# ('Seattle', 'OVAL')
# ('Yakima', 'OTHER')
# ('Palmdale', 'DISK')
# ('Sacramento', 'CIGAR')
# ("Chadd's Ford", 'CYLINDER')
# ('New Jersey', 'CIGAR')
# ('Watervliet', 'DISK')
# ('Vassalboro', 'OVAL')
# ('Silverfdale', 'VARIOUS')
# ('Santa Ana', 'DISK')
# ('Cape Canaveral', 'FIREBALL')
# ('Philadelphia', 'SPHERE')
# ('Barstow-Baker', 'DISK')
# ('Great Falls', 'FORMATION')
# ('Quincy', 'DISK')
# ('Baltimore', 'OTHER')
# ('Kansas City', 'DISK')
# ('Chicago', 'OVAL')
# ('East Bernstadt', 'DISK')
# ('Albertson', nan)
# ('Litchfield', 'OTHER')
# ('Portland', 'DISK')
# (nan, 'DISK')
# ('Stevens', 'OTHER')
# ('Portland', nan)
# ('New Berlin', 'CIRCLE')
# ('Springdale', 'FORMATION')
# ('La Verne', 'CIRCLE')
# ('Pacific Coast Highway', nan)
# ('Goldsboro', 'SPHERE')
# ('Amarillo', 'DIAMOND')
# ('Upland', 'CIRCLE')
# ('Allentown', 'CYLINDER')
# ('Taftville', 'DISK')
# ('Boston', 'DISK')
# ('Carteret', 'CIGAR')
# ('Crystal', 'CIRCLE')
# ('Cherokee', 'FIREBALL')
# ('Belmont', 'CIRCLE')
# ('Watchung', 'CIGAR')
# ('Cottonwood', nan)
# ('Saugus', 'CIRCLE')
# ('Framingham', 'OVAL')
# ('Long Beach', 'OTHER')
# ('Pittsburgh', 'SPHERE')
# ('Dickinson', 'CIRCLE')
# ('Buffalo', 'OVAL')
# ('Wichita', 'OVAL')
# ('Kingsport', 'CIRCLE')
# ('Seattle', 'DISK')
# ('Susanville', nan)
# ('Kaneohe', 'LIGHT')
# ('Burnsville', nan)
# ('Westbury', 'DISK')
# ('Sumner', 'SPHERE')
# ('Kansas City', nan)
# ('Santa Clara', 'CIRCLE')
# ('Kendallville', 'CIRCLE')
# ('Lancaster', 'DISK')
# ('Panhandle', 'DIAMOND')
# ('McGuire AFB', 'SPHERE')
# ('New York City', 'CROSS')
# ('Shenandoah', 'LIGHT')
# ('Altus', 'CIRCLE')
# ('Auburn', 'CIGAR')
# ('Parris Island', 'VARIOUS')
# ('Alpine', 'DISK')
# ('no data', 'TEARDROP')
# ('Opa Locka', 'OTHER')
# ('Carrollton', nan)
# ('Huntsville', 'TRIANGLE')
# ('Richardson', 'LIGHT')
# ('Frederick', 'LIGHT')
# ('Chicago', 'DISK')
# ('Webster Groves', 'CIRCLE')
# ('Dallas', 'DISK')
# ('Greensboro', 'CIGAR')
# ('Orlando', 'DISK')
# ('La Mirada', 'CIGAR')
# ('Rotan', 'SPHERE')
# ('Lawrenceville', 'CIRCLE')
# ('West Haven', 'LIGHT')
# ('Sapulpa', nan)
# ('Gettysburg', 'CIGAR')
# ('Mount Hope', nan)
# ('Newberg', 'EGG')
# ('Arlington Heights', 'DISK')
# ('Mill Valley', 'DISK')
# ('Glenshaw', 'DISK')
# ('Pittsburgh', 'SPHERE')
# ('Palatine', 'DISK')
# ('New York City', 'DISK')
# ('Evendale', nan)
# ('Fort Benning', 'DISK')
# ('Toledo', 'LIGHT')
# ('Wahoo', 'EGG')
# ('Toledo', 'SPHERE')
# ('Tulsa', 'DISK')
# ('Nashville', 'DISK')
# ('Graham', 'TRIANGLE')
# ('Bristol', 'SPHERE')
# ('Indialantic', 'OVAL')
# ('Bakersfield', 'CIRCLE')
# ('Leesville', 'FLASH')
# ('Bartow', 'SPHERE')
# ('Forestburg', 'SPHERE')
# ('Key West', 'SPHERE')
# ('Fayetteville', 'CIRCLE')
# ('Snohomish', 'DIAMOND')
# ('Wendover', 'DISK')
# ('Clayton', nan)
# ('Camden', 'SPHERE')
# ('Shenandoah', 'LIGHT')
# ('Huntingdon', nan)
# ('Acoma', 'CYLINDER')
# ('Toms River', 'DISK')
# ('Pittsburg', 'VARIOUS')
# ('Whitehouse', 'LIGHT')
# ('Garland', 'DISK')
# ('Bartlesville', nan)
# ('Charleston', 'DISK')
# ('Ellwood City', 'DISK')
# ('Liberty Homes', 'SPHERE')
# ('San Francisco', 'CIRCLE')
# ('Aurora', 'LIGHT')
# ('Benton', 'DISK')
# ('Lempster', 'CIRCLE')
# ('Castle Rock', 'SPHERE')
# ('Lawrence County', 'DISK')
# ('Booneville', 'DISK')
# ('IL', 'DISK')
# ('Joyce', 'OTHER')
# ('Ossining', nan)
# ('Orlando', 'SPHERE')
# ('Granada Hills', 'SPHERE')
# ('Cadiz', nan)
# ('Royal Oak', 'DISK')
# ('Bethpage', 'TRIANGLE')
# ('Bay Area', 'DISK')
# ('Miami', 'OVAL')
# ('Chicago', 'DISK')
# ('Seattle', 'OTHER')
# ('Spearman', nan)
# ('Lindsay', 'CYLINDER')
# ('Tannersville', 'LIGHT')
# ('Avon-by-the-Sea', 'VARIOUS')
# ('Chicago', 'OTHER')
# ('East Windsor', 'CIRCLE')
# ('Frankfort', 'OVAL')
# ('Mentor', 'DISK')
# ('Sunrise Beach', 'CYLINDER')
# ('Burkesville', 'DISK')
# ('Springdale', 'LIGHT')
# ('Rensselaer', 'OTHER')
# ('Savannah', 'DISK')
# ('Beaverton', 'TRIANGLE')
# ("Ship's Bottom", nan)
# ('Lodi', 'OTHER')
# ('Wellington', nan)
# ('Denver', 'DISK')
# ('Nenana', 'OVAL')
# ('Ann Arbor', 'DISK')
# ('Haverhill', 'DISK')
# ('San Juan Island', 'DISK')
# ('Seattle', 'CIRCLE')
# ('Hopewell', 'LIGHT')
# ('St. Louis', 'SPHERE')
# ('Wisconsin', 'DISK')
# ('Severn', nan)
# ('Island Beach State Park', 'DISK')
# ('Savannah', 'OVAL')
# ('Ft. Lee', nan)
# ('Chicago', 'OTHER')
# ('Valparaiso', 'CIGAR')
# ('Pharr', 'CHEVRON')
# ('Alameda Naval Air Station', nan)
# ('Runge', 'SPHERE')
# ('New York City', 'CIGAR')
# ('Markleville', 'DISK')
# ('Helena', 'DIAMOND')
# ('Holyoke', 'DISK')
# ('Cape May Court House', nan)
# ('Husten', nan)
# ('Normandy Park', 'CYLINDER')
# ('Great Lakes', 'DISK')
# ('Tucson', 'TRIANGLE')
# ('Vero Beach', 'DISK')
# ('Russellton', 'SPHERE')
# ('Lompoc', 'DISK')
# ('Alexandria', 'LIGHT')
# ('Lynn', 'DISK')
# ('New York City', 'OTHER')
# ('Towson', 'OVAL')
# ('Tishimingo', 'VARIOUS')
# ('Emporia', 'RECTANGLE')
# ('Cocoa', nan)
# ('Houston', nan)
# ('San Francisco', 'DISK')
# ('St. Louis County', 'CIGAR')
# ('Williamsport', 'OTHER')
# ('Gonzales', 'CIGAR')
# ('Albemarle', 'DISK')
# ('Houston', 'CIGAR')
# ('Kirksey', 'TRIANGLE')
# ('Waukegan', 'FORMATION')
# ('Royal Oak', 'TRIANGLE')
# ('Laguna Beach', 'LIGHT')
# ('Rodeo', 'SPHERE')
# ('Big Kandiyohi Lake', 'LIGHT')
# ('Colorado Springs', 'DISK')
# ('Fort Collins', 'CIGAR')
# ('Menasha', 'CIRCLE')
# ('Hollywood', 'DISK')
# ('Milford', 'OTHER')
# ('Washougal', nan)
# ('North St. Paul', 'DISK')
# ('Jonesboro', 'CIGAR')
# ('Sacramento', 'CYLINDER')
# ('Newaygo', 'SPHERE')
# ('Trion', 'CIRCLE')
# ('Newburgh', 'OTHER')
# ('Mansfield', 'LIGHT')
# ('Johnstown', 'RECTANGLE')
# ('Zebulon', 'OTHER')
# ('Newark', 'DISK')
# ('Salt Lake City', 'DISK')
# ('Anaheim', 'DISK')
# ('New York City', 'OVAL')
# ('Jonesboro', 'DISK')
# ('Lincoln', 'OTHER')
# ('Lincoln', 'OTHER')
# ('Tucson', 'OTHER')
# ('East Vassalboro', 'TRIANGLE')
# ('Evanston', 'DISK')
# ('Albert Lea', 'OVAL')
# ('Hornell', nan)
# ('Mantua', 'CIRCLE')
# ('Weingarten', 'DISK')
# ('Kimberling City', 'DISK')
# ('Great Lakes', 'DISK')
# ('Great Lakes', 'CIRCLE')
# ('Virginia Beach', 'CIRCLE')
# ('Oklahoma City', 'LIGHT')
# ('Santa Ana', 'LIGHT')
# ('Portland', 'SPHERE')
# ('Boston', 'TRIANGLE')
# ('Tupelo', 'DISK')
# ('Amsterdam', 'DISK')
# ('Compton', 'LIGHT')
# ('Wenatchee', 'FORMATION')
# ('Fresno', 'OTHER')
# ('Riverside', 'DISK')
# ('Claycomo', nan)
# ('Camas', nan)
# ('Broadalbin', 'LIGHT')
# ('Belchertown', nan)
# ('New York City', 'CIRCLE')
# ('Millington', 'DISK')
# ('Prince George', 'DISK')
# ('Laurel', 'OVAL')
# ('Danville', 'DISK')
# ('Engelwood Cliffs', nan)
# ('Rome', 'OVAL')
# ('El Cerrito', 'FIREBALL')
# ('Omaha', 'SPHERE')
# ('Bristow', nan)
# ('Cherry Valley', 'CIRCLE')
# ('Fries', 'CYLINDER')
# ('Miami', 'OTHER')
# ('Valley Station', 'OTHER')
# ('Bancroft', 'LIGHT')
# ('Seattle', 'DISK')
# ('Orangevale', 'LIGHT')
# ('Rangely', nan)
# ('Pineville', nan)
# ('Hardwick', 'DISK')
# ('Texarkana', 'DISK')
# ('Covina', 'CIGAR')
# ('Covina', 'CIGAR')
# ('Walden', 'CIGAR')
# ('Cave Springs', nan)
# ('Haltom City', 'LIGHT')
# ('Sallisaw', 'LIGHT')
# ('Butler', nan)
# ('Los Angeles', 'DISK')
# ('North Yakima', 'CIRCLE')
# ('New York City', 'DISK')
# ('Baltimore', 'SPHERE')
# ('Montrose', 'LIGHT')
# ('Chicago', 'CIRCLE')
# ('Auburndale', 'CIRCLE')
# ('Dedham', 'CIRCLE')
# ('Reno', 'DISK')
# ('Winnamucca', 'LIGHT')
# ('Miami', 'LIGHT')
# ('Great Falls', 'SPHERE')
# ('Tulsa', 'CIRCLE')
# ('Milan', 'SPHERE')
# ('Anchorville', 'DISK')
# ('Marble Falls', 'LIGHT')
# ('Destrehan', 'LIGHT')
# ('Tucson', 'TRIANGLE')
# ('Thompson', 'DISK')
# ('Alexandria', 'DISK')
# ('Atlanta', 'VARIOUS')
# ('Ontonagon', 'RECTANGLE')
# ('Hoquiam', 'OTHER')
# ('Ft. Wayne', 'TRIANGLE')
# ('Lewistown', 'OTHER')
# ('Paloma', 'OTHER')
# ('Laurel Springs', 'OTHER')
# ('Omaha', 'DISK')
# ('Wautoma', 'LIGHT')
# ('no data', 'LIGHT')
# ('Chicago', 'DISK')
# ('Defiance', 'LIGHT')
# ('Drew', 'CIRCLE')
# ('Hamilton', 'OVAL')
# ('Dayton', 'DISK')
# ('Brunswick', 'FORMATION')
# ('Washington', 'OTHER')
# ('Fishersville', 'FIREBALL')
# ('Las Vegas', 'CIRCLE')
# ('Rosebush', nan)
# ('New Jersey', 'LIGHT')
# ('Holden', 'LIGHT')
# ('Stonington', 'DISK')
# ('Chicago', 'FORMATION')
# ('Duquesne', 'CIGAR')
# ('Samuel-', 'FIREBALL')
# ('Charlestown', 'LIGHT')
# ('Morro Bay', 'TRIANGLE')
# ('Boston', 'CIRCLE')
# ('Bonfield', 'DIAMOND')
# ('Taylorville', 'DISK')
# ('Portland', 'CIRCLE')
# ('St. Louis', 'FIREBALL')
# ('Atlantic Ocean', 'CIGAR')
# ('Los Angeles', 'CROSS')
# ('St. Petersburg', nan)
# ('Florence', 'DISK')
# ('Oxen Hill', 'OVAL')
# ('East Hartford', 'FIREBALL')
# ('New York City', 'DISK')
# ('Spartanburg', 'DISK')
# ('Crescent Junction', 'DISK')
# ('Arcade', 'DISK')
# ('Yakima', 'DISK')
# ('Cowpens', 'DISK')
# ('Monterey', 'DISK')
# ('Chicago', 'SPHERE')
# ('Mt. Prospect', 'DISK')
# ('Mt. Prospect', 'DISK')
# ('Wilmington', nan)
# ('Terrebonne', 'CIGAR')
# ('Bettendorf', 'OTHER')
# ('Columbus', 'CIGAR')
# ('New Iberia', 'CIRCLE')
# ('Detroit', 'CIRCLE')
# ('Cotullia', 'SPHERE')
# ('Glen Allen', 'DISK')
# ('Memphis', 'CIRCLE')
# ('Memphis', 'SPHERE')
# ('Memphis', 'CIRCLE')
# ('Mokena', 'LIGHT')
# ('Conway', 'LIGHT')
# ('St. Ansgar', 'FIREBALL')
# ('Indianapolis', 'CIRCLE')
# ('Seattle', 'SPHERE')
# ('Chicago', 'OVAL')
# ('Metairie', 'CIRCLE')
# ('Jonesboro', 'DISK')
# ('Waterville', 'EGG')
# ('Austin', nan)
# ('Schertz', 'DISK')
# ('Nesquehoning', 'TRIANGLE')
# ('Daytona Beach', 'CIGAR')
# ('Tampa', 'DISK')
# ('Orlando', 'DISK')
# ('Newtown Square', 'TRIANGLE')
# ('Guernsey', 'SPHERE')
# ('York County', 'OVAL')
# ('Appelton', 'DISK')
# ('St. Louis County', 'CIGAR')
# ('Scotland', 'OTHER')
# ('Massapequa Park', 'OVAL')
# ('Burlington', 'DISK')
# ('Gadsden', 'SPHERE')
# ('La Mesa', 'DISK')
# ('Shasta Lake', 'DISK')
# ('Norman', 'DISK')
# ('St. Louis', 'SPHERE')
# ('Deming', 'DISK')
# ('Laconia', 'CYLINDER')
# ('Marathon', 'DISK')
# ('Knobnoster', 'OVAL')
# ('Long Beach', 'CYLINDER')
# ('Scottsville', 'LIGHT')
# ('Lakewood', 'DISK')
# ('Newport', 'LIGHT')
# ('Chicago', 'LIGHT')
# ('Fallon', nan)
# ('Miami', 'OVAL')
# ('Rochester', 'SPHERE')
# ('San Lorenzo', 'LIGHT')
# ('Toledo', 'SPHERE')
# ('Caliham', 'LIGHT')
# ('College Park', 'CIRCLE')
# ('Rustburg', 'LIGHT')
# ('Whittier', 'OTHER')
# ('Woodland HIlls', 'CIRCLE')
# ('West Corners', 'OTHER')
# ('Glenvil', nan)
# ('Thomson', 'CIRCLE')
# ('Hurley', 'CHEVRON')
# ('New Kensington', 'DISK')
# ('Utica', 'DISK')
# ('Mesquite', 'OVAL')
# ('Oklahoma City', 'SPHERE')
# ('St. Petersburg', nan)
# ('St. Marys', 'DISK')
# ('Medford', 'OVAL')
# ('Delano', 'FORMATION')
# ('Pottstown', 'OTHER')
# ('Wellington', nan)
# ('Albuquerque', 'DISK')
# ('Portland', 'DISK')
# ('Philadelphia', 'CIGAR')
# ('Vassalboro', 'DISK')
# ('Cadotte Pass', nan)
# ('Colville', 'FLASH')
# ('Tampa', nan)
# ('Montgomery', 'DISK')
# ('Brentwood', nan)
# ('Mount Shasta', 'CIGAR')
# ('Ocala', 'CIGAR')
# ('Elkins', 'DISK')
# ('Chesapeake', 'EGG')
# ('Blasdell', 'OVAL')
# ('Otisville', nan)
# ('Fountain Valley', 'SPHERE')
# ('Ringwood', 'DISK')
# ('Mt. Vernon', 'DISK')
# ('Moberly', 'LIGHT')
# ('New Orleans', nan)
# ('Narragansett', 'EGG')
# ('Panama City Beach', 'FIREBALL')
# ('Hains Falls', 'LIGHT')
# ('Winnemucca', 'LIGHT')
# ('Waterford', 'VARIOUS')
# ('Hudson', 'LIGHT')
# ('Oak Park', nan)
# ('San Fernando', 'OTHER')
# ('Fayetteville', 'CIRCLE')
# ('Los Angeles', 'CIGAR')
# ('Tehachapi', 'TRIANGLE')
# ('Jackson', 'RECTANGLE')
# ('San Gabriel', 'OVAL')
# ('Sistersville', 'FIREBALL')
# ('Westbury', 'EGG')
# ('Nyona Lake', 'CIGAR')
# ('Hornick', 'FIREBALL')
# ('Stoughton', 'LIGHT')
# ('Whitesburg', 'LIGHT')
# ('Aurora', 'SPHERE')
# ('Mansfield', 'DISK')
# ('Pittsfield', 'DISK')
# ('Pulaski', 'FIREBALL')
# ('Harrisburg', 'OVAL')
# ('Santa Ana', 'CIRCLE')
# ('Portland', 'DISK')
# ('Highland', 'SPHERE')
# ('Concord', nan)
# ('Norwalk', 'LIGHT')
# ('Old Lyme', 'OVAL')
# ('Pell Lake', 'EGG')
# ('Wilson', 'DISK')
# ('Potter', nan)
# ('St. Louis', 'SPHERE')
# ('Virden', 'SPHERE')
# ('Pearland', 'LIGHT')
# ('Pittsburgh', 'OVAL')
# ('San Clemente', 'FIREBALL')
# ('San Antonio', 'EGG')
# ('South Yarmouth', 'LIGHT')
# ('Tularosa', 'DISK')
# ('Minneapolis', 'VARIOUS')
# ('Hollis', 'SPHERE')
# ('Culver City', 'OVAL')
# ('Virginia Beach', 'DISK')
# ('Dillon', 'OVAL')
# ('Fort Ord', 'TRIANGLE')
# ('Tahlequah', 'OVAL')
# ('Sullivan', 'LIGHT')
# ('Oneonta', 'OVAL')
# ('Beaverton', 'CIGAR')
# ('Aurora', 'SPHERE')
# ('Roseville', 'DISK')
# ('West Lafayette', 'DISK')
# ('Vernon', 'LIGHT')
# ('Lowell', 'FIREBALL')
# ('Lowell', 'SPHERE')
# ('Charleston', 'SPHERE')
# ('New York City', 'CYLINDER')
# ('New York City', 'CYLINDER')
# ('Rutland', 'CIGAR')
# ('Jefferson City', 'SPHERE')
# ('Spotswood', 'CYLINDER')
# ('New Kensington', 'CIGAR')
# ('Indianapolis', 'EGG')
# ('Titusville', 'TRIANGLE')
# ('Terrebonne', 'LIGHT')
# ('Great Bend', 'VARIOUS')
# ('Kennewick', 'OVAL')
# ('Waterville', 'CIRCLE')
# ('Desert', 'DISK')
# ('Biloxi', 'OTHER')
# ('Colonial Heights', 'SPHERE')
# ('Dushore', 'DISK')
# ('Pittsburgh', 'DISK')
# ('Studio City', nan)
# ('Reseda', 'DISK')
# ('Norwalk', 'DISK')
# ('Pittsburgh', 'CIRCLE')
# ('Pittsburgh', 'DISK')
# ('Ponca City', nan)
# ('New Rochelle', 'SPHERE')
# ('Tabor', 'OVAL')
# ('Beverly', 'CYLINDER')
# ('La Jolla', nan)
# ('La Jolla', 'DISK')
# ('La Jolla', 'DISK')
# ('Joppatown', 'FIREBALL')
# ('Danvers', 'EGG')
# ('Billerica', 'CIGAR')
# ('B-52; inflight', 'LIGHT')
# ('Jacksonville', 'LIGHT')
# ('Old Saybrook', 'LIGHT')
# ('Middletown', 'SPHERE')
# ('Syosset', 'DISK')
# ('Colmar Manor', nan)
# ('New York City', 'OVAL')
# ('Cherokee', 'OTHER')
# ('Poughkeepsie', 'TRIANGLE')
# ('Grand Island', 'FIREBALL')
# ('Newtown Square', 'FIREBALL')
# ('Pittsburgh', nan)
# ('Fairmont', 'OTHER')
# ('Mantua', 'CIGAR')
# ('Enfield', 'CIRCLE')
# ('Enfield', 'CIRCLE')
# ('Enfield', 'FIREBALL')
# ('Enfield', 'FIREBALL')
# ('Middletown', 'FIREBALL')
# ('San Marcos', 'LIGHT')
# ('Spartanburg', 'OVAL')
# ('Houston', 'FORMATION')
# ('Davidsville', 'LIGHT')
# ('Bellmar', 'TRIANGLE')
# ('Flagstaff', 'DISK')
# ('Leavenworth', 'TRIANGLE')
# ('Fort Smith', 'CIRCLE')
# ('Ft. Smith', nan)
# ('Randolph', 'OVAL')
# ('Kent', 'DISK')
# ('Bakersfield', 'DISK')
# ('Gibralter', 'DISK')
# ('Ann Arbor', nan)
# ('Ft. Worth area', 'CYLINDER')
# ('Childs', 'CIRCLE')
# ('Warren', 'SPHERE')
# ('St Joseph', 'LIGHT')
# ('North Stonington', 'DISK')
# ('Elizabeth', 'CHEVRON')
# ('Hillsdale', 'DISK')
# ('El Paso', 'OVAL')
# ('Auburn', 'CIGAR')
# ('Roscoe', 'CHEVRON')
# ('Dearborn', 'CHEVRON')
# ('Dearborn', 'OVAL')
# ('Richmond', 'DISK')
# ('New Braintree', 'CIRCLE')
# ('Corpus Christi', 'LIGHT')
# ('Geneva', 'DISK')
# ('Interior', 'DISK')
# ('Hingham', 'OVAL')
# ('Francis E Warren AFB', nan)
# ('Atwater', 'OTHER')
# ('Reading', 'OTHER')
# ('Bonney Lake area', nan)
# ('Kent', 'SPHERE')
# ('Omaha', 'CIGAR')
# ('Michigan City', 'RECTANGLE')
# ('Beltsville', 'SPHERE')
# ('Tulsa', 'RECTANGLE')
# ('East Liverpool', 'TRIANGLE')
# ('Gering', nan)
# ('Nanakuli', 'DISK')
# ('Mentone', 'EGG')
# ('no data', 'DISK')
# ('Lexington', 'OTHER')
# ('Holly', 'LIGHT')
# ('Fort Lee', 'LIGHT')
# ('International Falls', 'DISK')
# ('New Rochelle', 'LIGHT')
# ('Gainesville', 'DISK')
# ('Old Washoe City', 'DISK')
# ('Bellingham', 'DISK')
# ('Chicago', 'DISK')
# ('Punxsutawney', nan)
# ('Carson City', 'DISK')
# ('Glenvil', nan)
# ('Betteravia', 'OTHER')
# ('Coyanosa', 'DISK')
# ('Odessa', 'OTHER')
# ('Miramar NAS', 'DISK')
# ('Cambridge', 'DISK')
# ('Grandview', 'TRIANGLE')
# ('Pleasantville', 'DISK')
# ('Dearborn Heights', 'DISK')
# ('District Heights', 'DISK')
# ('Oil City', 'SPHERE')
# ('Conshohocken', 'DISK')
# ('Billings', 'LIGHT')
# ('Sonoma', 'CIGAR')
# ('Sonoma', 'CIGAR')
# ('Hickory', 'DISK')
# ('Hickory', 'DISK')
# ('Ypsilanti', 'DISK')
# ('Playa del Rey', 'LIGHT')
# ('Vermontville', 'OVAL')
# ('Mexia', 'OVAL')
# ('Baltimore', 'OVAL')
# ('Stoughton', 'SPHERE')
# ('Columbus', 'CIRCLE')
# ('Roseburg', 'OTHER')
# ('Salem', 'OVAL')
# ('Reading', 'SPHERE')
# ('Oakdale', 'DISK')
# ('Monterey Bay', 'DISK')
# ('Cincinnati', 'DISK')
# ('Glendale', 'CIRCLE')
# ('McClellandtown', 'DISK')
# ('Bellevue', 'DISK')
# ('Toutle River', nan)
# ('Whiteman AFB', 'DISK')
# ('Duluth', 'DISK')
# ('Newington', 'TRIANGLE')
# ('Greenhills', 'DISK')
# ('Huntington', 'DISK')
# ('Little Axe', 'LIGHT')
# ('Rapid City', nan)
# ('Rapid City', 'DISK')
# ('Manor', 'OVAL')
# ('New Mexico', 'DISK')
# ('Mendota', 'DISK')
# ('New York City', 'CIRCLE')
# ('Washington', 'CIRCLE')
# ('Lake Cushman', 'OTHER')
# ('Montague', 'OTHER')
# ('Jonesboro', 'DISK')
# ('Corning', 'DISK')
# ('Wayne', 'CIGAR')
# ('Blocksburg', 'DISK')
# ('Peoria', 'CIGAR')
# ('Spartanburg', 'LIGHT')
# ('Santa Fe', 'DISK')
# ('Auburn', 'OTHER')
# ('Winston-Salem', 'OTHER')
# ('Dover', 'DISK')
# ('New Salem', 'OVAL')
# ('Jarrettsville', 'LIGHT')
# ('New Salem', 'SPHERE')
# ('Milton', 'LIGHT')
# ('Malden', 'SPHERE')
# ('Grand Prairie', 'OTHER')
# ('Cape Rosier', 'LIGHT')
# ('San Jose', 'DISK')
# ('Interlachen', 'FIREBALL')
# ('Hopkinsville', 'OTHER')
# ('Dracut', 'CIRCLE')
# ('Springfield', 'OTHER')
# ('Galveston', 'OVAL')
# ('La Puente', 'TRIANGLE')
# ('Centerville', 'LIGHT')
# ('Cold Springs', nan)
# ('Malibu', 'TRIANGLE')
# ('Waukegan', 'CIRCLE')
# ('Gahanna', 'LIGHT')
# ('Douglas', 'CIGAR')
# ('Columbus', 'CIRCLE')
# ('Garden City', 'CIGAR')
# ('Santa Rosa', 'DISK')
# ('Newcastle', nan)
# ('Ovando', 'OVAL')
# ('Caseyville', 'LIGHT')
# ('Renton', 'OVAL')
# ('Rochester', 'OTHER')
# ('Amherst', 'DISK')
# ('Galesburg', 'DISK')
# ('Seattle', 'DISK')
# ('Bass Harbor', 'DISK')
# ('Beverly', 'CIGAR')
# ('Big Sur', 'DIAMOND')
# ('Indianapolis', 'LIGHT')
# ('Seatac', nan)
# ('Grovertown', 'CIGAR')
# ('Rochester', 'DISK')
# ('New York City', 'SPHERE')
# ('Bakersfield', 'CIRCLE')
# ('Columbus', 'CIRCLE')
# ('Pasco', 'DISK')
# ('Hundred', 'OVAL')
# ('Terre Haute', 'SPHERE')
# ('Clifton', 'FLASH')
# ('Delta Junction', 'CIGAR')
# ('Canoga Park', 'CIGAR')
# ('Toledo', 'TRIANGLE')
# ('Huntington', 'TRIANGLE')
# ('Chicago', 'CIGAR')
# ('Granby', nan)
# ('Los Banos', 'EGG')
# ('Norfolk', 'OVAL')
# ('Red Oak', 'OVAL')
# ('Coventry', 'CIRCLE')
# ('Huntington', 'CIRCLE')
# ('Buffalo', 'LIGHT')
# ('Anacortes', 'LIGHT')
# ('Anamosa', nan)
# ('Corvallis', 'DISK')
# ('Troy', nan)
# ('Pell City', 'DISK')
# ('Live Oak', 'DISK')
# ('Mission', 'DISK')
# ('Boca Raton', 'CIRCLE')
# ('Martinsville', 'DISK')
# ('Running  Springs', 'DISK')
# ('Ukiah', 'OVAL')
# ('Utica', 'TRIANGLE')
# ('Fremont', nan)
# ('Albuquerque', 'DIAMOND')
# ('Santa Fe', 'DISK')
# ('Gulfport', 'EGG')
# ('Miami', nan)
# ('North Dade County', nan)
# ('Opa Locka', 'CHEVRON')
# ('Opa Locka', 'CYLINDER')
# ('Opa Locka', 'DISK')
# ('Kodiak Naval Station', 'FORMATION')
# ('Seattle', 'DISK')
# ('Hempstead', nan)
# ('Jacksonville', 'CHEVRON')
# ('Corpus Christi', 'OVAL')
# ('Huntington Beach', 'CIRCLE')
# ('Winston-Salem', 'TRIANGLE')
# ('Wanaque', 'OVAL')
# ('Webster City', 'SPHERE')
# ('Valley Forge', 'SPHERE')
# ('Phoenixville', 'OVAL')
# ('Salem', 'DISK')
# ('Rockford', nan)
# ('Hammond', 'TRIANGLE')
# ('Opa Locka', 'CHEVRON')
# ('Forbes AFB', 'DISK')
# ('Fort Bliss', 'DISK')
# ('Martin', 'DISK')
# ('Lakeview', 'OTHER')
# ('Stony Point', nan)
# ('Andover', 'LIGHT')
# ('Meriden', nan)
# ('Whittier', 'OVAL')
# ('Hickman', 'FORMATION')
# ('Oak Grove', nan)
# ('Mt. Washington', 'CIRCLE')
# ('San Angelo', 'CIRCLE')
# ('Norwalk', 'CIGAR')
# ('Galesburg', 'OVAL')
# ('Valdosta', 'DISK')
# ('Opa Locka', nan)
# ('Opa Locka', 'OVAL')
# ('Las Vegas', 'LIGHT')
# ('Homestead', nan)
# ('Tampa', 'LIGHT')
# ('Miami', 'OTHER')
# ('Albany', nan)
# ('middle of desert', 'LIGHT')
# ('Miami', 'DISK')
# ('Nashville', 'DISK')
# ('Westbury', 'FORMATION')
# ('El Paso', 'CHEVRON')
# ('North Hollywood', 'FORMATION')
# ('Stamford', 'CYLINDER')
# ('Gibson', 'OVAL')
# ('Chattahoochee', 'LIGHT')
# ('Enid', 'DISK')
# ('Maryville', 'CIGAR')
# ('Hallandale', 'TRIANGLE')
# ('Fallon', 'OVAL')
# ('Kent', 'DISK')
# ('Gainesville', 'TRIANGLE')
# ('Belvedere', 'TEARDROP')
# ('Palm Wells', 'FORMATION')
# ('Monroe', 'LIGHT')
# ('El Paso', 'LIGHT')
# ('Bangor', nan)
# ('Bangor', nan)
# ('Farmersville', 'CIRCLE')
# ('Oxen Hill', 'SPHERE')
# ('Shofield Barracks-Civilian', 'VARIOUS')
# ('Edgemoor', 'DISK')
# ('Fort Knox', 'CYLINDER')
# ('St. Paul', 'DISK')
# ('San Diego', 'CIRCLE')
# ('El Cerrito', 'OVAL')
# ('Red Oak', 'LIGHT')
# ('Warrensburg on Highway 13', 'OTHER')
# ('Cordova', 'DISK')
# ('West Bend', 'LIGHT')
# ('Myrtle Creek', 'CIRCLE')
# ('Cincinnati', 'CIGAR')
# ('Sumner', 'FORMATION')
# ('Gerry', 'DISK')
# ('Laddonia', nan)
# ('Yucca Valley', 'LIGHT')
# ('Hyde Park', 'OTHER')
# ('Ventura', 'CIGAR')
# ('Boise', 'DISK')
# ('Decatur', 'LIGHT')
# ('Tacoma', 'OTHER')
# ('Cedar Rapids', 'OVAL')
# ('El Paso', 'LIGHT')
# ('Poteau', 'LIGHT')
# ('Thomasville', 'OTHER')
# ('DeSoto', 'LIGHT')
# ('Kent', 'DISK')
# ('Highway', 'CIRCLE')
# ('Detroit', 'SPHERE')
# ('China Lake', 'SPHERE')
# ('Edison', 'OTHER')
# ('Glens Falls', 'TEARDROP')
# ('Oak Ridge', 'SPHERE')
# ('Arbuckle', 'TRIANGLE')
# ('Salt Lake City', 'DISK')
# ('Savannah', 'CHEVRON')
# ('Baker', 'DISK')
# ('Fairfield', 'CIGAR')
# ('Boise', 'LIGHT')
# ('none', 'DISK')
# ('Glendale', 'LIGHT')
# ('Peoria', 'DISK')
# ('Kansas city', 'OTHER')
# ('Lander', 'LIGHT')
# ('Oakwood', 'CIRCLE')
# ('Goleta', nan)
# ('Pine River', 'LIGHT')
# ('Portmouth', 'DISK')
# ('Reidsville', 'CIRCLE')
# ('Slidell', 'CIRCLE')
# ('Lansing', 'LIGHT')
# ('Schofield Barracks', 'CIRCLE')
# ('Aiken', 'OVAL')
# ('Ft. Lewis', 'LIGHT')
# ('Glenview', 'CIRCLE')
# ('New Market', 'TRIANGLE')
# ('Maury Mountains', 'FIREBALL')
# ('Chatfield', nan)
# ('Corpus Christi', 'OTHER')
# ('East Hanover', 'CIGAR')
# ('Colorado Springs', 'TRIANGLE')
# ('Fort Smith', 'TRIANGLE')
# ('Wyoming', 'CIGAR')
# ('Marshfield', 'DISK')
# ('Carmichaels', 'CHEVRON')
# ('Boydstown', 'DISK')
# ('Lakeville', 'FORMATION')
# ('Sacramento', 'LIGHT')
# ('Barboursville', 'SPHERE')
# ('Crystal Beach', 'DISK')
# ('West Lake', 'CIRCLE')
# ('West Palm Beach', 'FIREBALL')
# ('Churchville', 'DISK')
# ('Wadsworth', 'OTHER')
# ('Marathon County', 'DISK')
# ('Coxsackie', 'CIRCLE')
# ('New York City', 'DIAMOND')
# ('Roseburg', 'SPHERE')
# ('Downey', nan)
# ('Davis Park', 'TRIANGLE')
# ('Sturgeon Bay', 'CIGAR')
# ('Fort Smith', 'CHEVRON')
# ('Fort Smith', 'CHEVRON')
# ('Fort Smith', 'TEARDROP')
# ('Middlesboro', 'OVAL')
# ('Babylon', 'CIRCLE')
# ('Alamosa', 'LIGHT')
# ('Little Rock', 'CIRCLE')
# ('Chicago', 'TRIANGLE')
# ('Albuquerque', 'CIGAR')
# ('Westford', nan)
# ('Melbourne', nan)
# ('Burien', 'LIGHT')
# ('Sag Harbor', 'SPHERE')
# ('Lee Vining', 'DISK')
# ('Gula', 'CIRCLE')
# ('Camden', 'VARIOUS')
# ('Edgartown', 'SPHERE')
# ('Huron', 'CIGAR')
# ('Azusa Canyon', nan)
# ('Pittsburgh', 'CIRCLE')
# ('Fort Lauderdale', 'CIGAR')
# ('Princeton', 'DISK')
# ('Playa del Rey', 'OVAL')
# ('Fort Mitchell', 'DISK')
# ('Lansing', nan)
# ('Bentonia', 'LIGHT')
# ('Winchester', 'CIGAR')
# ('North Royalton', 'DISK')
# ('Crestone', 'FIREBALL')
# ('Corydon', 'DISK')
# ('Beatrice', 'DISK')
# ('Baltimore', nan)
# ('Hermosa Beach', 'CIGAR')
# ('Brownville', 'CIRCLE')
# ('Portsmouth', 'OTHER')
# ('Atlanta', 'CIGAR')
# ('Caribou', 'DISK')
# ('Cedar Point', 'LIGHT')
# ('Chiloquin', 'DISK')
# ('Schofield Barracks Military area', 'CIRCLE')
# ('Santa Rosa', 'CIRCLE')
# ('Woodland Hills', 'TRIANGLE')
# ('Tipp City', 'LIGHT')
# ('Albuquerque', nan)
# ('Lone Rock', 'OVAL')
# ('Chaffee', 'SPHERE')
# ('Greenville', 'CIRCLE')
# ('Minneapolis', 'DISK')
# ('Syracuse', 'DISK')
# ('Whippany', 'DISK')
# ('Lantana', 'OTHER')
# ('Birmingham', 'OVAL')
# ('Hampstead', 'DISK')
# ('North Hollywood', 'FIREBALL')
# ('Saugus', 'LIGHT')
# ('Travis AFB', nan)
# ('Cherokee Village', 'CIRCLE')
# ('Old Greenwich', 'DISK')
# ('Midland', 'LIGHT')
# ('Ada', 'CIRCLE')
# ('Tiburon', 'TEARDROP')
# ('Fort Polk', nan)
# ('Clearmont', nan)
# ('Chicago', 'DISK')
# ('Blaine', nan)
# ('Silver Lake', nan)
# ('Broadview Heights', 'LIGHT')
# ('La Plata', 'CIRCLE')
# ('Bithlo', 'DISK')
# ('Burlington', 'CIRCLE')
# ('Lawndale', 'CIRCLE')
# ('West Monroe', 'LIGHT')
# ('Wheaton', 'CIRCLE')
# ('Tucson', 'DISK')
# ('Jacksonville', nan)
# ('American Falls', 'DISK')
# ('Anjean', 'OVAL')
# ('Gloucester', 'DISK')
# ('Carpinteria', 'SPHERE')
# ('Dayton', 'DISK')
# ('on plane wing', 'DISK')
# ('Temple', 'LIGHT')
# ('Ironwood', 'SPHERE')
# ('New York City', 'DISK')
# ('Alamosa', 'SPHERE')
# ('Savannah', 'CIRCLE')
# ('Gainesville', 'CIGAR')
# ('Little Rock', 'CYLINDER')
# ('Westland', 'DISK')
# ('Columbia Station', 'SPHERE')
# ('Walla Walla', 'TRIANGLE')
# ('Scottsville', 'DISK')
# ('Overton', 'OVAL')
# ('Las Vegas', 'SPHERE')
# ('Silver City', 'CIRCLE')
# ('New Kensington', 'CIRCLE')
# ('Redfield', 'CONE')
# ('Franconia Notch', 'CIRCLE')
# ('Valparaiso', nan)
# ('Valparaiso', nan)
# ('Omaha', 'DISK')
# ('St. Louis', 'OVAL')
# ('Stevens Point', 'SPHERE')
# ('Jones', 'OVAL')
# ('Provo', 'SPHERE')
# ('Towaco', 'CIRCLE')
# ('Morehead', 'LIGHT')
# ('Delta', 'SPHERE')
# ('Binghamton', 'DISK')
# ('Clovis', 'CIGAR')
# ('Sanford', 'FIREBALL')
# ('Dayton', 'OVAL')
# ('Chicago', 'OVAL')
# ('Las Vegas', 'LIGHT')
# ('Camden', 'CIRCLE')
# ('Corry', 'FIREBALL')
# ('Billings', 'CIRCLE')
# ('Ash Grove', 'SPHERE')
# ('Fairfield', 'CIGAR')
# ('Gadsden', 'OTHER')
# ('Columbia', 'TRIANGLE')
# ('Monmouth Junction', 'LIGHT')
# ('Winnie', 'FIREBALL')
# ('Zanesville', 'DISK')
# ('Houston', 'TRIANGLE')
# ('Mississippi', 'CIRCLE')
# ('Renton', 'VARIOUS')
# ('Minot', 'CIGAR')
# ('Rocky Mountains', 'OTHER')
# ('Rocky Mountains', 'OTHER')
# ('Lake Havasu City', 'CIGAR')
# ('Duluth', 'DISK')
# ('NAS Fallon', 'DISK')
# ('Minot', 'DISK')
# ('State College', 'OVAL')
# ('Downers Grove', 'DISK')
# ('Woodland Hills', 'DISK')
# ('St. Paul', 'CIRCLE')
# ('Shrewsbury', 'RECTANGLE')
# ('Coyanosa', 'LIGHT')
# ('Panama City', 'LIGHT')
# ('Greensboro', 'TRIANGLE')
# ('Akron', 'DISK')
# ('Canoga Park', 'CYLINDER')
# ('Fort Hood', 'DISK')
# ('Baytown', 'CIGAR')
# ('Bishop', 'DISK')
# ('Louisville', nan)
# ('Oak Cliff', 'DISK')
# ('Oak Cliff', 'DISK')
# ('Pasadena', 'CIGAR')
# ('Livingston', 'DISK')
# ('Allentown', 'SPHERE')
# ('Pittsburgh', 'LIGHT')
# ('Wytheville', 'DISK')
# ('Brevard', 'CIRCLE')
# ('Mariposa', nan)
# ('Mojave Desert', 'LIGHT')
# ('Garden Valley', 'DISK')
# ('Salt Lake City', 'LIGHT')
# ('Fairfield', 'OTHER')
# ('York', 'EGG')
# ('Badlands', nan)
# ('Upper Lisle', 'TRIANGLE')
# ('Honolulu', 'CIRCLE')
# ('Wyoming', 'DISK')
# ('Cottonwood', 'CIRCLE')
# ('Thurmont', 'DISK')
# ('Harahan', 'LIGHT')
# ('Chicago', nan)
# ('Whittier', 'SPHERE')
# ('Hueytown', 'OVAL')
# ('Auburn', 'OTHER')
# ('Ponca City', 'LIGHT')
# ('Gardendale', 'DISK')
# ('Gilmer', 'CIGAR')
# ('Yankton', nan)
# ('Christmas Valley', 'DISK')
# ('Hillsboro', nan)
# ('Oldtown', 'DISK')
# ('Stockton', 'DISK')
# ('Dallas', 'OTHER')
# ('Tempe', 'TRIANGLE')
# ('Plantsville', 'LIGHT')
# ('New Castle', 'DISK')
# ('Salt Lake City', 'CIRCLE')
# ('Cincinnati', 'DISK')
# ('Santa Barbara', 'FORMATION')
# ('Vega', 'DISK')
# ('Otis Air Force Base', 'LIGHT')
# ('Otis Air Force Base', 'LIGHT')
# ('Thomasville', nan)
# ('Houston', 'DISK')
# ('Augusta', 'TRIANGLE')
# ('Rumson', 'DISK')
# ('Nashville', 'CIGAR')
# ('Quantico Marine Base', 'CIGAR')
# ('Perth Amboy', 'CIRCLE')
# ('North Little Rock', 'CIRCLE')
# ('Norwich', 'DIAMOND')
# ('Bena', 'VARIOUS')
# ('Phoenix', 'LIGHT')
# ('Pyramid Lake Indian Reservation', 'LIGHT')
# ('Seattle', 'CIRCLE')
# ('Rosemead', 'CIGAR')
# ('Homeworth', 'TRIANGLE')
# ('Marion', 'OTHER')
# ('Columbus', 'OTHER')
# ('Stillwater', 'FIREBALL')
# ('Martinez', 'DISK')
# ('Des Moines', 'CIRCLE')
# ('Cleveland Heights', 'OVAL')
# ('Zell', 'DISK')
# ('San Jose', 'CIRCLE')
# ('Oakland', 'CIGAR')
# ('Brainerd', 'CIRCLE')
# ('Freeport', 'DISK')
# ('Draffenville', 'DISK')
# ('Corpus Christi', 'OTHER')
# ('Baytown', 'LIGHT')
# ('Coxsackie', 'CIRCLE')
# ('Panama City Beach', 'LIGHT')
# ('Georgetown', 'OTHER')
# ('Pollack Pines', 'LIGHT')
# ('Lake Dorothy', 'DISK')
# ('Cherry Hill', 'DISK')
# ('Eugene', 'CIGAR')
# ('Vineland', 'FIREBALL')
# ('Niantic', 'DISK')
# ('Morro Bay', 'LIGHT')
# ('Byron', 'DISK')
# ('Ft. Benning', 'SPHERE')
# ('Austin', 'DISK')
# ('Yosemite Pass', 'DISK')
# ('Sewickley', 'CIGAR')
# ('Cannon', 'OVAL')
# ('Church Hill', 'SPHERE')
# ('East Palestine', 'DISK')
# ('Pomona', 'LIGHT')
# ('Greensboro', 'DISK')
# ('Kansas Ciy', 'VARIOUS')
# ('Norfolk Naval Operation Base', 'CIRCLE')
# ('Elwood', 'CIGAR')
# ('Gulf of Mexico', 'OVAL')
# ('Tracy', nan)
# ('Santa Rosa', 'CIRCLE')
# ('Corydon', 'DISK')
# ('Colorado Springs', 'SPHERE')
# ('Tontitown', nan)
# ('White Owl', 'FIREBALL')
# ('Oelwein', 'CIGAR')
# ('covington', 'CIRCLE')
# ('Edison', 'DISK')
# ('Edison', 'DISK')
# ('Edison', 'DISK')
# ('Boston', 'CIGAR')
# ('Kennebunkport', 'CIRCLE')
# ('London Mills', 'DISK')
# ('Nunda', 'DISK')
# ('Hawthorne', 'CIRCLE')
# ('Brevard', 'FIREBALL')
# ('Hastings', 'TRIANGLE')
# ('Crystal Lake', 'CIGAR')
# ('Bancroft', 'LIGHT')
# ('Fort Polk', 'LIGHT')
# ('Shadyside', 'OVAL')
# ('Ashtabula', 'DISK')
# ('Bullskin', 'CIRCLE')
# ('Wayne', 'OVAL')
# ('Lakeland', 'DISK')
# ('Walla Walla', 'OTHER')
# ('Springfield', 'DISK')
# ('Miami', 'FIREBALL')
# ('Loring AFB', nan)
# ('Enid', 'FLASH')
# ('Nacaome', 'OVAL')
# ('San Diego', nan)
# ('Ocean off Miami', 'LIGHT')
# ('Kent', 'TRIANGLE')
# ('Locust Fork', 'LIGHT')
# ('Gasconade', nan)
# ('Abbeville', 'DISK')
# ('Logansport', 'CIGAR')
# ('Joshua Tree National Park', 'FLASH')
# ('Hollywood', 'OTHER')
# ('Juneau', 'OTHER')
# ('Juneau', 'OTHER')
# ('Greensburg', nan)
# ('Farmerville', 'OTHER')
# ('Nevada test site', 'TRIANGLE')
# ('Naples', 'OVAL')
# ('Pittsburgh', 'OTHER')
# ('Butte', 'RECTANGLE')
# ('Miami', 'SPHERE')
# ('Butte', 'OTHER')
# ('Lake Wales', 'DISK')
# ('Monroe', 'SPHERE')
# ('Omaha', 'OVAL')
# ('Oak Lawn', 'DISK')
# ('Perth Amboy', 'LIGHT')
# ('Oroville', 'CROSS')
# ('Little Axe', 'CIGAR')
# ('Loganville', 'CIGAR')
# ('City of Commerce', 'CIGAR')
# ('At sea', 'LIGHT')
# ('Little Rock', 'CYLINDER')
# ('Youngstown', 'DISK')
# ('Ridgefield', nan)
# ('San Diego', 'OVAL')
# ('Wheaton', 'DISK')
# ('Estill', 'CIGAR')
# ('St. Louis', 'CIGAR')
# ('Dallas', 'LIGHT')
# ('Wilshire', 'SPHERE')
# ('Boulder', 'OTHER')
# ('Wacousta', 'SPHERE')
# ('Kyle', 'OVAL')
# ('La Puenty', 'FORMATION')
# ('Sarasota', 'LIGHT')
# ('Barrington', 'SPHERE')
# ('Highwood', 'DISK')
# ('Oahu', 'LIGHT')
# ('Highwood', 'DISK')
# ('Falls Church', 'OTHER')
# ('HWY 77', nan)
# ('Lawrenceburg', 'DISK')
# ('Sausalito', nan)
# ('Akron', 'LIGHT')
# ('Athens', 'RECTANGLE')
# ('Orangevale', nan)
# ('Philadelphia', 'CIRCLE')
# ('Chance', 'DISK')
# ('Windsor', 'DISK')
# ('Portland', 'DISK')
# ('North Wildwood', 'TRIANGLE')
# ('Whitmore Lake', 'LIGHT')
# ("Land O'Lakes", 'DISK')
# ('Islip', 'OTHER')
# ('Grang junction colorado', 'DISK')
# ('Little Rock', 'CYLINDER')
# ('Kent', 'OTHER')
# ('Altoona', 'OTHER')
# ('Bryan', 'TRIANGLE')
# ('Fairfax', 'OVAL')
# ('Ronkonkoma', nan)
# ('Moline', nan)
# ('Fort Lauderdale', 'OTHER')
# ('Kyle', 'OVAL')
# ('Westphalia', 'EGG')
# ('Christmas Valley', 'DISK')
# ('Holliston', nan)
# ('Detroit', 'LIGHT')
# ('Indianapolis', 'DISK')
# ('Bristol', nan)
# ('Issaquah', 'DISK')
# ('Scottsdale', nan)
# ('Whittier', 'DISK')
# ('New York Mills', 'DISK')
# ('Payson', 'DISK')
# ('Chambers County', 'CIRCLE')
# ('Lakewood', 'OTHER')
# ('Sunnyvale', 'DISK')
# ('Cachuma Lake', 'OTHER')
# ('Jacksonville Beach', 'OTHER')
# ('March AFB', 'TRIANGLE')
# ('Valdez', 'DISK')
# ('Fresno', 'OTHER')
# ('Brainerd', 'TRIANGLE')
# ('Miami', 'LIGHT')
# ('Salt Lake City', 'CIRCLE')
# ('Chariton', 'CIRCLE')
# ('Upper Dublin', 'SPHERE')
# ('Whitemarsh', 'FIREBALL')
# ('Bridgeport', 'CIGAR')
# ('South Glens', 'FLASH')
# ('Geneseo', nan)
# ('Enid', nan)
# ('Wasco', 'DISK')
# ('Cape Canaveral', 'SPHERE')
# ('Champaign', 'DISK')
# ('Peoria', 'DISK')
# ('Fairfax', 'DISK')
# ('Somerville', 'LIGHT')
# ('Burlington', 'OTHER')
# ('Hawley', 'CIRCLE')
# ('Rocky Mount', 'SPHERE')
# ('Akron', 'CIRCLE')
# ('Summerville', 'LIGHT')
# ('Independence', 'SPHERE')
# ('Ohio', 'OTHER')
# ('Dayton', 'DISK')
# ('Fort Lauderdale', 'LIGHT')
# ('New Castle', 'OVAL')
# ('Minnetonka', 'LIGHT')
# ('North Haven', 'DISK')
# ('Barstow', 'LIGHT')
# ('Port Chester', 'OTHER')
# (nan, 'CIRCLE')
# ('Baldwin City', 'CIRCLE')
# ('Johnstown', 'TRIANGLE')
# ('Port Jefferson', 'DISK')
# ('El Cajon', 'OTHER')
# ('East Barre', 'CYLINDER')
# ('Rockford', 'OTHER')
# ('Biola', 'CIGAR')
# ('Lamont', 'FORMATION')
# ('North Hollywood', 'SPHERE')
# ('Enfield', 'OVAL')
# ('Walpole', 'OVAL')
# ('Austin', 'SPHERE')
# ('Merced', nan)
# ('Fairbanks', 'CIGAR')
# ('Raceland', 'TRIANGLE')
# ('San Francisco', 'OVAL')
# ('Millington', 'FORMATION')
# ('Memphis', 'FORMATION')
# ('Sharon', 'OVAL')
# ('Pearl', 'CIGAR')
# ('Portland', 'CIGAR')
# ('Wilmington', 'CIRCLE')
# ('Hurst', 'DISK')
# ('Miami', 'VARIOUS')
# ('Exeter', 'CIGAR')
# ('Alpine', 'DISK')
# ('Erie', 'CIRCLE')
# ('Fulton', 'CIGAR')
# ('Fulton', 'CIGAR')
# ('Fulton', 'CIGAR')
# ('Fulton', 'CIRCLE')
# ('San Juan Capistrano', nan)
# ('Fairbanks', 'FORMATION')
# ('Camp Pendleton', 'LIGHT')
# ('Hogans Camp Resort', 'CIRCLE')
# ('Buford', 'DISK')
# ('San Jose', 'LIGHT')
# ('Kenai', 'LIGHT')
# ('Glenmore', 'CIRCLE')
# ('Richmond', 'CIRCLE')
# ('Middletown', 'FIREBALL')
# ('Middletown', 'CIRCLE')
# ('Rogersville', nan)
# ('Joplin', nan)
# ('Grand Rapids', 'DISK')
# ('Candia', 'LIGHT')
# ('Hemet', 'CYLINDER')
# ('Lake Wales', 'OVAL')
# ('Danville', 'EGG')
# ('San Mateo', 'SPHERE')
# ('Denver', 'CIGAR')
# ('Los Angeles', 'DISK')
# ('Colorado Springs', nan)
# ('Lafayette', 'DISK')
# ('Ft. Dix', 'CIRCLE')
# ('Columbus', 'OTHER')
# ('Cutler Ridge', 'LIGHT')
# ('St. Petersburg', 'DISK')
# ('Monessen', 'CYLINDER')
# ('Fort Worth', 'DISK')
# ('Camp Pendleton', 'DISK')
# ('Slocomb', 'CIRCLE')
# ('Interstate 40', 'LIGHT')
# ('East Aurora', 'EGG')
# ('Evansville', 'DISK')
# ('New York City', 'OTHER')
# ('New York City', 'OTHER')
# ('Houston', 'DISK')
# ('Oak Ridge', 'DISK')
# ('La Grange', 'CIRCLE')
# ('New York City', 'VARIOUS')
# ('Kansas City', 'LIGHT')
# ('Vero Beach', 'OVAL')
# ('Tampa', 'OVAL')
# ('Reading', 'TRIANGLE')
# ('Ritter', 'DISK')
# ('Hopewell', 'DISK')
# ('Burlingame', 'DISK')
# ('Hilmar', 'DISK')
# ('Rogers Dry Lake', 'OVAL')
# ('Columbus', 'DISK')
# ('Fulton', 'CIRCLE')
# ('Medford', 'OVAL')
# ('New York City', 'DISK')
# ('Westfield', 'DISK')
# ('Russia', nan)
# ('Cleveland', 'DISK')
# ('Downers Grove', 'DISK')
# ('Maui', 'EGG')
# ('Not sure', 'DISK')
# ('Eureka', 'OVAL')
# ('Kalispell', 'CIGAR')
# ('Princess Anne', 'OVAL')
# ('Huntington', nan)
# ('West Ocean City', 'LIGHT')
# ('Geneseo', nan)
# ('Houston', 'DISK')
# ('Oxford', 'OTHER')
# ('Milford', 'DISK')
# ('San Bruno Mountain Ranges', 'DISK')
# ('Yorktown Heights', 'LIGHT')
# ('Chicago', 'CIRCLE')
# ('CT', 'CIRCLE')
# ('River Pines', 'DISK')
# ('Snowbank Lake', 'DISK')
# ('Malibu Canyon', nan)
# ('Whitmire', 'CIRCLE')
# ('Cheyenne', 'CIRCLE')
# ('West Jefferson', 'SPHERE')
# ('Poughkeepsie', 'DISK')
# ('Honolulu', 'SPHERE')
# ('Kent', 'DISK')
# ('San Antonio', 'OVAL')
# ('Warren', 'DISK')
# ('Lockport', 'LIGHT')
# ('McLean', 'OTHER')
# ('La Habra', 'SPHERE')
# ('Lansing', 'LIGHT')
# ('Bemus Point', 'OTHER')
# ('Provo', 'DISK')
# ('South Windsor', 'OVAL')
# ('Indian Orchard', nan)
# ('Tyre', 'OTHER')
# ('Roseville', 'DISK')
# ('Pittsfield', 'LIGHT')
# ('Pearl Harbor', nan)
# ('Custer', 'LIGHT')
# ('Englewood', 'SPHERE')
# ('Kindred', 'OVAL')
# ('Levittown', 'DISK')
# ('Newark', 'OVAL')
# ('Grand Blanc', nan)
# ('Grand Blanc', 'LIGHT')
# ('Stockton', 'FIREBALL')
# ('Cottonwood', 'CYLINDER')
# (nan, nan)
# ('Racine', nan)
# ('Pompano Beach', 'OTHER')
# ('Everton', 'LIGHT')
# ('Palmdale', 'CYLINDER')
# ('Ocean City', 'DISK')
# ('Newport', 'RECTANGLE')
# ('Seymore', 'DISK')
# ('Spring City', 'FIREBALL')
# ('Sebastian', nan)
# ('Toms River', 'SPHERE')
# ('Brady', 'CIRCLE')
# ('Brady', 'DISK')
# ('Los Angeles', 'DISK')
# ('Pittsburgh', 'DISK')
# ('Mundelin', 'DISK')
# ('San Angelo', 'LIGHT')
# ('Deer Creek', 'DIAMOND')
# ('Sturgeon', nan)
# ('Russellton', 'TRIANGLE')
# ('Quincy', nan)
# ('Homestead', 'LIGHT')
# ('New York City', 'SPHERE')
# ('New York City', 'DISK')
# ('Bentonville', 'OTHER')
# ('Summit Lake Indian Reservation', 'OVAL')
# ('Tampa', 'OTHER')
# ('New York City', 'DISK')
# ('Bellmore', 'DISK')
# ('Manchester', nan)
# ('Westland', nan)
# ('San Diego', 'LIGHT')
# ('Lindenhurst', 'SPHERE')
# ('Corpus Christi', 'OVAL')
# ('Rochester', nan)
# ('Beardstown', 'LIGHT')
# ('Franklin', 'SPHERE')
# ('Columbus', 'SPHERE')
# ('Somerville', 'DISK')
# ('Union', 'DISK')
# ('Albuquerque', 'OTHER')
# ('Newton Centre', 'OTHER')
# ('Meriden', nan)
# ('Lake  Wales', 'OVAL')
# ('Colorado Springs', 'RECTANGLE')
# ('Berlin', 'CYLINDER')
# ('Tewksbury', nan)
# ('Waverly Hall', 'CIRCLE')
# ('Gorham', 'LIGHT')
# ('Conshohocken', 'CIRCLE')
# ('Havensville', 'CIRCLE')
# ('Everglades', 'DISK')
# ('Savannah', 'CIRCLE')
# ('Deltona', 'VARIOUS')
# ('Los Angeles', 'OTHER')
# ('Boulder Creek', 'CIGAR')
# ('Santa Rosa', 'LIGHT')
# ('Orlando', 'DISK')
# ('Talladega', 'DISK')
# ('Osceola', 'DISK')
# ('Carrolton', 'CIRCLE')
# ('Dennis', nan)
# ('Rural New Mexico', 'TRIANGLE')
# ('Burlington', 'CIRCLE')
# ('Thomasville', 'DISK')
# ('Lewisburg', 'TRIANGLE')
# ('Cherokee', 'LIGHT')
# ('Molson', 'CIRCLE')
# ('New Martinsville', 'LIGHT')
# ('Cowpen', 'CONE')
# ('Irmo', 'CIRCLE')
# ('Kennett Square', 'DISK')
# ('Palos Verde', 'SPHERE')
# ('Holliday', 'DISK')
# ('Newport', 'LIGHT')
# ...
# ('Ocean City', 'FIREBALL')
# ('San Angelo', 'LIGHT')
# ('Clearwater', 'DISK')
# ('Edgerton', 'DIAMOND')
# ('Sea-Tac', 'EGG')
# ('Orange', 'CIRCLE')
# ('Phoenix', 'LIGHT')
# ('Hatfield', 'RECTANGLE')
# ('Boca Raton', 'CIRCLE')
# ('Vandenberg Village', 'CIRCLE')
# ('Harrisonville', 'FIREBALL')
# ('Forest Hills', 'FORMATION')
# ('New York City', 'DISK')
# ('Red Lion', 'FIREBALL')
# ('Tampa', 'CIRCLE')
# ('Youngstown', nan)
# ('Enfield', 'LIGHT')
# ('Fountain Hills', 'OTHER')
# ('Katy', 'FIREBALL')
# ('Allentown', 'DISK')
# ('Highlands Ranch', nan)
# ('Astoria', 'LIGHT')
# ('Tonawanda', 'VARIOUS')
# ('Emporia', 'DISK')
# ('Evanston', 'CONE')
# ('Levittown', 'CIRCLE')
# ('Cordova', 'FLASH')
# ('Pawleys Island', 'OTHER')
# ('Boston', 'LIGHT')
# ('Roseville', 'RECTANGLE')
# ('Palmdale', 'CIRCLE')
# ('Norcross', 'FIREBALL')
# ('Carolina Beach', 'CIRCLE')
# ('Henderson', 'OTHER')
# ('Redmond', 'LIGHT')
# ('New Hampton', 'LIGHT')
# ('Eastvale', 'CIRCLE')
# ('Wilkes-Barre', 'LIGHT')
# ('Sioux Falls', 'TEARDROP')
# ('Moore', 'TRIANGLE')
# ('Milton Freewater', 'TRIANGLE')
# ('Pekin', 'DIAMOND')
# ('Dubois', 'LIGHT')
# ('Dubois', 'OTHER')
# ('Donnelly', 'FORMATION')
# ('Clarksville', nan)
# ('McKinney', 'RECTANGLE')
# ('Santa Barbara', 'VARIOUS')
# ('Cypress', 'TRIANGLE')
# ('North Highlands', 'CIGAR')
# ('Fort Fisher', 'CIRCLE')
# ('Lexington', 'LIGHT')
# ('South Chicago Height', nan)
# ('Wailua', 'LIGHT')
# ('Wilmington', 'FIREBALL')
# ('Clifton Park', 'FIREBALL')
# ('Clifton Park', 'OTHER')
# ('Bradenton', 'FIREBALL')
# ('Sacramento', 'OTHER')
# ('Harpers Ferry', 'CIRCLE')
# ('Comfort', 'LIGHT')
# ('Valdosta', 'LIGHT')
# ('Las Vegas', 'FLASH')
# ('Martinsville', 'TRIANGLE')
# ('North Fort Myers', 'LIGHT')
# ('Pearland', 'CONE')
# ('New Bern', 'VARIOUS')
# ('Newark', 'CIRCLE')
# ('Grand Rapids', nan)
# ('Oceanside', 'RECTANGLE')
# ('Bernardston', nan)
# ('Washington Township', 'OTHER')
# ('Catawba', 'VARIOUS')
# ('Kill Devil Hills', nan)
# ('Frisco', 'FIREBALL')
# ('Swan Quarters', 'OVAL')
# ('Sarcoxie', 'LIGHT')
# ('San Gabriel Valley', 'CIRCLE')
# ('Sunset Beach', 'CIRCLE')
# ('Tulsa', 'TRIANGLE')
# ('Northborough', nan)
# ('Camdenton', nan)
# ('Fenwick Island', 'CIRCLE')
# ('Harrington', 'LIGHT')
# ('Morongo Valley', 'LIGHT')
# ('Las Vegas', 'SPHERE')
# ('Provincetown', 'CIRCLE')
# ('Myrtle Beach', 'CIRCLE')
# ('Glasgow', 'DISK')
# ('Lake Port', 'OTHER')
# ('Orlando', 'LIGHT')
# ('West Valley', nan)
# ('Austin', 'CIRCLE')
# ('Littleton', 'SPHERE')
# ('Walpole', 'RECTANGLE')
# ('Walton', nan)
# ('Austin', 'CIRCLE')
# ('Spokane', 'SPHERE')
# ('Nags Head', 'FIREBALL')
# ('New Orleans', 'FIREBALL')
# ('Oakland', 'CIRCLE')
# ('Columbus', 'CROSS')
# ('Green Bay', 'FIREBALL')
# ('Westland', 'CIRCLE')
# ('Warden', 'LIGHT')
# ('Takoma Park', 'FIREBALL')
# ('Harriman', 'LIGHT')
# ('Pass Christian', 'FIREBALL')
# ('Lumberton', 'FIREBALL')
# ('Greeley', 'TRIANGLE')
# ('Warrensburg', 'LIGHT')
# ('Westbury', 'DISK')
# ('Weiser', 'LIGHT')
# ('Houston', 'CIRCLE')
# ('Ocean City', 'FIREBALL')
# ('Charleston', 'TRIANGLE')
# ('Rochester', 'FORMATION')
# ('Miami', 'CIRCLE')
# ('Atlanta', 'CONE')
# ('Allentown', 'TRIANGLE')
# ('Hanover', nan)
# ('Wilmington', 'CIRCLE')
# ('Cheyenne', 'TRIANGLE')
# ('Shawnee', 'SPHERE')
# ('Dennis', 'CIRCLE')
# ('Houma', 'FIREBALL')
# ('La Grange', 'LIGHT')
# ('Easton', 'FIREBALL')
# ('Greeley', 'CIRCLE')
# ('Clinton', 'CIRCLE')
# ('Marina del Rey', 'LIGHT')
# ('Phoenixville', 'FIREBALL')
# ('Rapid City', 'LIGHT')
# ('Harrah', nan)
# ('Highlands Ranch', 'VARIOUS')
# ('Smithfield', 'FIREBALL')
# ('Rehoboth Beach', 'OVAL')
# ('Hanover', 'FIREBALL')
# ('Rolla', nan)
# ('Salt Lake City', 'TRIANGLE')
# ('Des Moines', 'LIGHT')
# ('Exeter', 'CIRCLE')
# ('Seattle', 'FORMATION')
# ('Seattle', 'LIGHT')
# ('Morgan', 'LIGHT')
# ('Holden', 'OVAL')
# ('McDonald', 'LIGHT')
# ('Newport', 'RECTANGLE')
# ('Boise', 'LIGHT')
# ('Sykesville', 'LIGHT')
# ('Luray', 'LIGHT')
# ('Memphis', nan)
# ('Morristown', 'TRIANGLE')
# ('Boulder Creek', 'CIRCLE')
# ('Kehei', 'LIGHT')
# ('Wahiawa', 'LIGHT')
# ('San Diego', 'OTHER')
# ('Johnston', 'OVAL')
# ('Omaha', 'LIGHT')
# ('Adams', 'FIREBALL')
# ('Phoenix', 'FLASH')
# ('Colonia', 'CIRCLE')
# ('Lexington', 'LIGHT')
# ('Manitowoc', 'FIREBALL')
# ('Clackamas', 'TRIANGLE')
# ('Borger', 'LIGHT')
# ('Rome', 'FIREBALL')
# ('Brookfield', 'LIGHT')
# ("Bailey's Harbor", 'LIGHT')
# ('Reading', nan)
# ('Rodanthe', 'FORMATION')
# ('Sesser', 'TRIANGLE')
# ('Kearns', 'LIGHT')
# ('Bellingham', 'LIGHT')
# ('Astoria', 'FIREBALL')
# ('Franklin', 'TRIANGLE')
# ('Grants Pass', 'FIREBALL')
# ('Madison', nan)
# ('Madison', nan)
# ('Salem', 'FORMATION')
# ('Belcamp', 'LIGHT')
# ('Oakland Park', 'TRIANGLE')
# ('Beaverton', 'OVAL')
# ('Roswell', 'OTHER')
# ('La Porte', 'OVAL')
# ('Waialua', 'LIGHT')
# ('Duck', 'CIRCLE')
# ('Wenatchee', 'CIRCLE')
# ('Waterford', 'OVAL')
# ('Arvada', 'OVAL')
# ('Cleveland', 'CIRCLE')
# ('Effingham', 'FIREBALL')
# ('Junction City', 'CIRCLE')
# ('Spokane', 'FIREBALL')
# ('Bellingham', 'DISK')
# ('Lilly', 'OTHER')
# ('Narragansett', 'FIREBALL')
# ('Glenpool', 'LIGHT')
# ('Portland', 'OTHER')
# ('Timmonsville', 'FIREBALL')
# ('Myrtle Beach', 'FIREBALL')
# ('Clairton', 'LIGHT')
# ('Round Rock', 'LIGHT')
# ('Lannon', 'LIGHT')
# ('Laguna Beach', 'LIGHT')
# ('Owasso', 'LIGHT')
# ('Billings', 'SPHERE')
# ('Helena', 'SPHERE')
# ('Boston', 'DISK')
# ('Yellowstone National Park', 'TEARDROP')
# ('Gresham', 'OTHER')
# ('Myrtle Beach', 'LIGHT')
# ('Skippack', 'CIRCLE')
# ('Buffalo', 'FIREBALL')
# ('Collegeville', 'LIGHT')
# ('Skippack', 'LIGHT')
# ('Stockton', 'RECTANGLE')
# ('Watertown', 'LIGHT')
# ('West Roxbury', nan)
# ('Baton Rouge', 'LIGHT')
# ('Vancouver', 'SPHERE')
# ('Tonawanda', 'LIGHT')
# ('North Myrtle Beach', 'CIRCLE')
# ('North Myrtle Beach', 'SPHERE')
# ('Bossier City', nan)
# ('Myrtle Beach', 'LIGHT')
# ('Cherry Grove', 'OVAL')
# ('Lilly', 'OTHER')
# ('Canyonlands National Park', nan)
# ('San Diego', 'LIGHT')
# ('Jacksonville', 'DISK')
# ('Talbott', 'DISK')
# ('Lakewood', 'OTHER')
# ('Adams', 'CIRCLE')
# ('Georgetown', 'OVAL')
# ('Corinth', 'FIREBALL')
# ('Hyannis', 'VARIOUS')
# ('Pearblossom', 'LIGHT')
# ('Pierre', 'CIRCLE')
# ('Sandusky', 'OTHER')
# ('Menard', 'LIGHT')
# ('Cleveland', 'LIGHT')
# ('Holden beach', 'CIRCLE')
# ('Willow Spring', nan)
# ('Duxbury', 'CIRCLE')
# ('Ocean Isle', nan)
# ('Ocean Isle Beach', 'LIGHT')
# ('Pendleton', 'OTHER')
# ('North Myrtle Beach', 'VARIOUS')
# ('Ochelata', 'CIRCLE')
# ('Myrtle Beach', 'DIAMOND')
# ('Sunset Beach', 'CIRCLE')
# ('Detroit', 'LIGHT')
# ('Myrtle Beach', 'RECTANGLE')
# ('Coalinga', 'LIGHT')
# ('Traverse City', 'FIREBALL')
# ('Waterbury', 'TRIANGLE')
# ('Carlinville', nan)
# ('Falcon', 'OTHER')
# ('Mesa', 'TRIANGLE')
# ('Meridian', 'LIGHT')
# ('Morton', 'SPHERE')
# ('Holden Beach', 'CIRCLE')
# ('Holden Beach', 'CIRCLE')
# ('Lehi', nan)
# ('St. Charles', 'TRIANGLE')
# ('Davie', 'FIREBALL')
# ('Topeka', 'DIAMOND')
# ('Port Neches', 'LIGHT')
# ('Oceanside', 'FIREBALL')
# ('Greenville', 'CIRCLE')
# ('New York City', 'FIREBALL')
# ('Pasadena', 'RECTANGLE')
# ('Pinehurst', 'LIGHT')
# ('Tulsa', 'TRIANGLE')
# ('Colden', 'CIRCLE')
# ('McDonough', 'CIRCLE')
# ('Palm City', 'CIRCLE')
# ('Chicago', 'FLASH')
# ('Lancaster', 'CYLINDER')
# ('San Marcos', 'LIGHT')
# ('Shirley', 'CIRCLE')
# ('Wantagh', 'FIREBALL')
# ('Memphis', 'LIGHT')
# ('Morrill', 'LIGHT')
# ('South Nags Head', 'CIRCLE')
# ('Kissimmee', nan)
# ('Colorado Springs', 'LIGHT')
# ('Rhawnhurst', 'TRIANGLE')
# ('Taveriner', 'FIREBALL')
# ('Greenville', 'TRIANGLE')
# ('Nashville', 'DIAMOND')
# ('Edmonds', 'LIGHT')
# ('Miami', 'LIGHT')
# ('Pikeville', 'LIGHT')
# ('Eugene', nan)
# ('Roswell', 'CIRCLE')
# ('Pueblo', 'FIREBALL')
# ('Barnsdall', nan)
# ('Georgie', 'TRIANGLE')
# ('Emerald Isle', 'CIRCLE')
# ('Kentwood', 'FIREBALL')
# ('Everett', 'LIGHT')
# ('Douglasville', 'FLASH')
# ('Lincoln Park', 'FORMATION')
# ('Sayreville', 'CIRCLE')
# ('Lolo', 'TRIANGLE')
# ('Naples', 'FIREBALL')
# ('Merced', 'FORMATION')
# ('Ringoes', 'SPHERE')
# ('Kingston', 'SPHERE')
# ('Oceanside', 'LIGHT')
# ('Columbus', 'LIGHT')
# ('Crown Point', 'LIGHT')
# ('Ridgecrest', 'FLASH')
# ('Washington', 'OVAL')
# ('New York City', 'CIRCLE')
# ('Aurora', 'FIREBALL')
# ('Crete', 'FIREBALL')
# ('Kaneville', nan)
# ('Orland', 'LIGHT')
# ('South Kingston', 'FIREBALL')
# ('Tallmadge', 'LIGHT')
# ('Sumter', 'LIGHT')
# ('Watkins Glen', 'CIRCLE')
# ('North Plains', 'TRIANGLE')
# ('Clarksburg', 'LIGHT')
# ('Morrisville', 'LIGHT')
# ('Auburn', 'FIREBALL')
# ('Cape Coral', 'LIGHT')
# ('Cherokee', 'DIAMOND')
# ('Kent', 'FIREBALL')
# ('Milwaukee', 'CIRCLE')
# ('South Lyon', 'FORMATION')
# ('Brick', 'CIRCLE')
# ('Monroe', 'FLASH')
# ('Coldwater', 'SPHERE')
# ('Enumclaw', 'LIGHT')
# ('St. Louis', 'DIAMOND')
# ('Atlanta', 'LIGHT')
# ('Cherokee', 'LIGHT')
# ('Lafayette', 'LIGHT')
# ('Newnan', 'FIREBALL')
# ('Piscataway', 'OVAL')
# ('Currie', nan)
# ('Old AL Hwy. 35', 'SPHERE')
# ('Atlanta', 'RECTANGLE')
# ('Morrisonville', 'LIGHT')
# ('Ontario', 'CIRCLE')
# ('North Myrtle Beach', 'SPHERE')
# ('Chattanooga', 'OVAL')
# ('Grand Rapids', nan)
# ('Madison', 'FIREBALL')
# ('St. Paul', 'LIGHT')
# ('Lincoln', 'LIGHT')
# ('Ledyard', 'OVAL')
# ('Sacramento', 'LIGHT')
# ('Newark', 'LIGHT')
# ('Shelbyville', 'CIRCLE')
# ('Manassas', 'TRIANGLE')
# ('Sacramento', 'FORMATION')
# ('Redmond', 'OTHER')
# ('Antonito', 'SPHERE')
# ('Atwater', 'CIGAR')
# ('North Lauderdale', 'CYLINDER')
# ('Amherst', 'FIREBALL')
# ('Norfolk', 'LIGHT')
# ('New Braunfels', 'LIGHT')
# ('Atascocita', 'CIRCLE')
# ('Vancouver', 'LIGHT')
# ('Cannon Beach', 'CIRCLE')
# ('Cherokee Pass', 'LIGHT')
# ('Tamarac', 'CIRCLE')
# ('Fort Pierce', 'FIREBALL')
# ('Dawsonville', 'CIRCLE')
# ('Kent', 'CIGAR')
# ('South Bethany Beach', 'CIRCLE')
# ('Hopewell', 'LIGHT')
# ('Dayton', nan)
# ('Marysville', 'OTHER')
# ('Scranton', 'CIRCLE')
# ('Murray', 'VARIOUS')
# ('Gunnison', 'OTHER')
# ('Dunn', 'LIGHT')
# ('Tempe', nan)
# ('Santa Barbara', 'LIGHT')
# ('Central Islip', 'LIGHT')
# ('Massillon', 'FIREBALL')
# ('Lake Forest', 'LIGHT')
# ('Long Beach', 'CIRCLE')
# ('Orlando', 'LIGHT')
# ('Staunton', 'CIRCLE')
# ('Peru', 'LIGHT')
# ('Corona', 'LIGHT')
# ('Crestline', 'LIGHT')
# ('Mission Viejo', nan)
# ('Portland', 'LIGHT')
# ('Oceanside', 'VARIOUS')
# ('Rutland', 'CIRCLE')
# ('Murrieta', 'LIGHT')
# ('Nags Head', 'LIGHT')
# ('Warwick', 'FLASH')
# ('Escondido', 'SPHERE')
# ('Aliso Viejo', 'FIREBALL')
# ('Rochester', 'TRIANGLE')
# ('Carlsbad', 'DISK')
# ('San Marcos', 'LIGHT')
# ('Brookfield', 'LIGHT')
# ('Tarlton', 'TRIANGLE')
# ('Charleston', 'CIRCLE')
# ('Lewistown', 'TRIANGLE')
# ('Savannah', 'LIGHT')
# ('Sarasota', 'FORMATION')
# ('Portland', nan)
# ('Lago Vista', 'TRIANGLE')
# ('Warwick', 'CYLINDER')
# ('Lake View area', 'TRIANGLE')
# ('Mesa', 'DISK')
# ('Hickory', 'FIREBALL')
# ('Bristol', 'LIGHT')
# ('Deatsville', 'LIGHT')
# ('Westmoreland', 'LIGHT')
# ('Colonia', nan)
# ('Ventura', 'LIGHT')
# ('Barto', 'CIRCLE')
# ('Bettendorf', 'TRIANGLE')
# ('Joplin', 'DISK')
# ('Edina', 'OTHER')
# ('Salyersville', 'LIGHT')
# ('St. Louis', 'TRIANGLE')
# ('Bethany Beach', 'FORMATION')
# ('South Bethany Beach', 'FORMATION')
# ('South Bethany Beach', 'FORMATION')
# ('East Stroudsburg', 'FLASH')
# ('Winchester', 'CIRCLE')
# ('North Liberty', 'DIAMOND')
# ('Duck', 'SPHERE')
# ('Battle Mountain', 'FLASH')
# ('Woodland Hills', 'CIGAR')
# ('Menifee', nan)
# ('Taunton', 'OVAL')
# ('Red Hook', 'FIREBALL')
# ('Phoenix', 'CIRCLE')
# ('Kenneth City', 'FIREBALL')
# ('Charleston', 'CIRCLE')
# ('Colquitt', 'CIGAR')
# ('Kahuku', 'LIGHT')
# ('Hyannis', 'SPHERE')
# ('Hyden', nan)
# ('Kenosha', 'OVAL')
# ('Sartell', nan)
# ('Clayton', 'LIGHT')
# ('Spanaway', 'LIGHT')
# ('Monroe', 'SPHERE')
# ('Wesley Chapel', 'OTHER')
# ('Santa Ysabel', 'OTHER')
# ('New Holland', nan)
# ('Columbus', 'FORMATION')
# ('Forks Township', 'CIRCLE')
# ('Glen Burnie', nan)
# ('Lititz', nan)
# ('Merrimack', 'LIGHT')
# ('Riverhead', 'OVAL')
# ('Sherwood', 'FIREBALL')
# ('Linthicum', 'FORMATION')
# ('S. Bethany Beach', nan)
# ('Phoenixville', 'CIRCLE')
# ('Massapequa', 'LIGHT')
# ('Marlborough', 'CIGAR')
# ('Gulfport', 'CIRCLE')
# ('Opihikao', 'LIGHT')
# ('Salt Lake City', 'LIGHT')
# ('Cherry Hill', 'LIGHT')
# ('Seattle', 'FORMATION')
# ('Henryetta', 'CIRCLE')
# ('Owings Mills', 'CYLINDER')
# ('San Francisco', 'RECTANGLE')
# ('Houston', 'TRIANGLE')
# ('Rancho Cucamonga', 'LIGHT')
# ('Enders', nan)
# ('Newark', nan)
# ('Sayville', 'FIREBALL')
# ('Manassas', 'CIGAR')
# ('Mount Rose Wilderness, Reno', 'OVAL')
# ('Pittsfield', 'CIRCLE')
# ('Salem', 'LIGHT')
# ('Boise', 'LIGHT')
# ('Fontana', 'CIGAR')
# ('Seattle', 'CIRCLE')
# ('Merrick', 'LIGHT')
# ('Hyden', 'RECTANGLE')
# ('Big Pine', 'FLASH')
# ('West Hills', 'TEARDROP')
# ('Folsom', 'TRIANGLE')
# ('Lockport', 'CIRCLE')
# ('Morgantown', 'DISK')
# ('East Northport', 'FIREBALL')
# ('Weirs Beach', 'LIGHT')
# ('Clarence Center', nan)
# ('Louisiana', 'LIGHT')
# ('Ocean Beach', 'CYLINDER')
# ('Syracuse', 'CIRCLE')
# ('Harleysville', 'CIRCLE')
# ('Shrewsbury', 'FORMATION')
# ('Oklahoma City', 'LIGHT')
# ('Troy', 'CROSS')
# ('Apple Valley', 'OVAL')
# ('Arlington Heights', 'CIRCLE')
# ('Blaine', 'CIRCLE')
# ('Breaux Bridge', 'LIGHT')
# ('New York City', 'CIRCLE')
# ('Snellville', 'RECTANGLE')
# ('North Charleston', 'CIRCLE')
# ('Satsop', 'LIGHT')
# ('Port Charlotte', 'FIREBALL')
# ('Spanaway', 'OVAL')
# ('Liverpool', 'TRIANGLE')
# ('Sykesville', 'SPHERE')
# ('Melbourne Beach', 'CIRCLE')
# ('Syracuse', 'DIAMOND')
# ('Des Moines', 'CIRCLE')
# ('San Francisco', 'RECTANGLE')
# ("Lee's Summit", 'CIRCLE')
# ('El Cajon', 'DIAMOND')
# ('Londonderry', 'CIRCLE')
# ('Houma', 'CIRCLE')
# ('Orlando', 'DISK')
# ('West Chester', 'FORMATION')
# ('Belvidere', nan)
# ('Mukwonago', 'FIREBALL')
# ('Mukwonago', 'FIREBALL')
# ('Salisbury', 'TRIANGLE')
# ('San Diego', 'LIGHT')
# ('Dayton', 'FORMATION')
# ('Penn Hills', 'CIRCLE')
# ('Fallbrook', 'FIREBALL')
# ('Virginia Beach', 'LIGHT')
# ('North Tonawanda', 'OTHER')
# ('Eugene', 'VARIOUS')
# ('Sioux Falls', 'CIRCLE')
# ('Charleston', 'SPHERE')
# ('Eustace', 'LIGHT')
# ('Racine', 'DISK')
# ('Cumberland', 'CIRCLE')
# ('Mankato', 'LIGHT')
# ('Saint Paul', 'LIGHT')
# ('Panama City', 'CIGAR')
# ('Palmer', 'LIGHT')
# ('Manteca', 'SPHERE')
# ('Glenpool', 'FORMATION')
# ('Stayton', 'FIREBALL')
# ('Demands', 'LIGHT')
# ('Bellingham', 'LIGHT')
# ('San Tan Valley', 'LIGHT')
# ('St. Louis Park', 'DISK')
# ('Cullowhee', nan)
# ('Bettendorf', 'CIRCLE')
# ('Pompton Lakes', 'SPHERE')
# ('Greenwood', 'CYLINDER')
# ('Racine', 'CIRCLE')
# ('Sabula', 'CHEVRON')
# ('Saline', 'CIRCLE')
# ('Hummelstown', 'RECTANGLE')
# ('Montrose', 'SPHERE')
# ('Dayton', 'SPHERE')
# ('Brunswick', 'CYLINDER')
# ('Dayton', 'FIREBALL')
# ('Elkhorn', 'FIREBALL')
# ('Scribner', 'TEARDROP')
# ('El Cajon', 'TRIANGLE')
# ('Eastport', nan)
# ('Topsail', 'LIGHT')
# ('Panama City Beach', 'OTHER')
# ('Missoula', 'LIGHT')
# ('Harrisburg', 'TRIANGLE')
# ('North Charleston', nan)
# ('Kihei', 'LIGHT')
# ('Silverton', 'OTHER')
# ('Rock Hill', 'LIGHT')
# ('Southwest desert', 'TRIANGLE')
# ('Minersville', 'TRIANGLE')
# ('Hobbs', 'FORMATION')
# ('Mountlake Terrace', 'SPHERE')
# ('Senoia', 'SPHERE')
# ('Syracuse', 'CIRCLE')
# ('Parma', 'FIREBALL')
# ('Roswell', 'CIRCLE')
# ('Concord', 'VARIOUS')
# ('Albuquerque', 'LIGHT')
# ('Revere', 'LIGHT')
# ('Galloway', 'LIGHT')
# ('Columbia', 'LIGHT')
# ('South Londonderry', 'VARIOUS')
# ('Rossmoor', 'SPHERE')
# ('Gold Hill', 'LIGHT')
# ('Hudson', nan)
# ('Milford', 'CIRCLE')
# ('Nampa', nan)
# ('Allentown', 'LIGHT')
# ('Wildwood', nan)
# ('Trevose', 'TRIANGLE')
# ('Monroe', 'TRIANGLE')
# ('Bowie', 'LIGHT')
# ('Fort Worth', 'OTHER')
# ('Albuquerque', 'CIRCLE')
# ('Newton', 'TEARDROP')
# ('Akron', 'CROSS')
# ('Aurora', nan)
# ('Logan', 'DIAMOND')
# ('Spearfish', 'FIREBALL')
# ('Fort Collins', 'TEARDROP')
# ('Gilbert', 'OTHER')
# ('Rapid City', 'FORMATION')
# ('Minot', 'CIRCLE')
# ('Manchester', 'LIGHT')
# ('Brentwood', 'TRIANGLE')
# ('Pleasure Island', 'SPHERE')
# ('Woodhaven', 'EGG')
# ('Jonesborough', 'CIGAR')
# ('Johnson City', nan)
# ('Auburn', 'CIRCLE')
# ('Boca Raton', 'CIRCLE')
# ('Kingston', 'FLASH')
# ('New York City', 'FLASH')
# ('Gastonia', 'SPHERE')
# ('Highland Park', 'LIGHT')
# ('Gooding', 'SPHERE')
# ('Johnsburg', 'LIGHT')
# ('Twin Falls', 'LIGHT')
# ('York', 'LIGHT')
# ('Bethel Park', 'VARIOUS')
# ('Lake Geneva', 'LIGHT')
# ('Clarence', 'TRIANGLE')
# ('Hanover', 'LIGHT')
# ('Buhl', 'LIGHT')
# ('Helena', 'LIGHT')
# ('Chesapeake Beach', 'CIRCLE')
# ('Rogersville', 'OVAL')
# ('Lawrence', 'LIGHT')
# ('Malta', 'LIGHT')
# ('Manahawkin', 'CIRCLE')
# ('New Bedford', 'LIGHT')
# ('Woodbridge', 'TRIANGLE')
# ('Glendale', 'CYLINDER')
# ('Laconia', 'CIGAR')
# ('Langhorne', 'OTHER')
# ('Glen Ellyn', 'CIRCLE')
# ('Waynesburg', 'FLASH')
# ('Canal Winchester', 'TRIANGLE')
# ('Lawrence', 'LIGHT')
# ('Ellicott City', 'LIGHT')
# ('Olympia', 'LIGHT')
# ('Iowa City', 'LIGHT')
# ('Marshfield', 'LIGHT')
# ('Seattle', 'DIAMOND')
# ('North Royalton', 'TRIANGLE')
# ('Deer Park', 'LIGHT')
# ('Glen St. Mary', 'DISK')
# ('Abingdon', 'CIRCLE')
# ('Lawrence', 'LIGHT')
# ('Melbourne', 'OVAL')
# ('Burleson', 'LIGHT')
# ('Elizabethtown', 'CIRCLE')
# ('Wyoming', 'DISK')
# ('Neligh', 'CIRCLE')
# ('Neligh', 'CIRCLE')
# ('Uhrichsville', 'LIGHT')
# ('Tucson', nan)
# ('Orland park', 'LIGHT')
# ('Loughman', 'LIGHT')

# %% [markdown]
# #### 6. With the subset, find the percent of each shape seen by city.

# %%
# A:

# %% [markdown]
# **7. Make a grouped bar chart with your subset data showing counts of shapes seen by city.**

# %%
# A:
